# %% [markdown]
# # Fecha de entrega: 27/08/2022 (corresponde a clase 20)

# %% [markdown]
# # Algoritmo de clasificación: Random forest

# %% [markdown]
# # Diccionario

# %% [markdown]
# **BTC_US_fv**
#
# - Date: fecha en YYYY-MM-DD (datetime64 [ns])
# - Price: precio de cierre de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Open: precio de apertura de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - High: precio más alto de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Low: precio más bajo de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Vol.: volumen de BTC (Número de intercambios) en el día de la fecha (float) (Variable numérica continua)
# - Percentage_diff: diferencia porcentual del precio de BTC en la fecha [x+1] con respecto a la fecha [x] (float) (Variable numérica continua)
# - Target: 1 indica que en el día de la fecha el precio de BTC subió, y 0 que el precio bajó (float) (Se la tratará como variable categórica)
# - Percentage_diff_USD_JPY: diferencia porcentual de la relación Dolar norteamericano y Yen japonés (float) (Variable numérica continua)
# - Price_SP500: indica el valor de cierre de la bolsa de valores S%P500 (USD) (Variable numérica continua)
# - Price_NASDAQ: indica el valor de cierre de la bolsa de valores NASDAQ (USD) (float) (Variable numérica continua)
# - Price_DJ: indica el valor de cierre de la bolsa de valores Dow Jones (USD) (float) (Variable numérica continua)
# - Price_US_Bond: indica el valor del bono a 10 años de EEUU (es uno de los bonos más relevantes a nivel macro) (float) (Variable numérica continua)
# - I_Percentage_diff_ACPI: indica la diferencia porcentual interanual entre los valores del Consumer Price Index (float) (inflación) (Variable numérica continua)
# - M_Percentage_diff_MCPI: indica la diferencia porcentual mensual entre los valores del Consumer Price Index (inflación) (float) (Variable numérica continua)
# - FEDfunds: indica la tara de inflación de EEUU (float) (Variable numérica continua)
# - Trend: tendencia de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)
# - Seasonality: estacionariedad de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)
# - Residuals: residualidad de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)
# - BTC_cycle: ciclicidad de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)

# %% [markdown]
# # Librerías

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas_profiling
import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib.cm import ScalarMappable

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor 

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('darkgrid')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Data acquisition

# %%
def gdriveColabPath(sharing_url):
  file_id=sharing_url.split('/')[-2]
  dwn_url='https://drive.google.com/uc?id=' + file_id
  return dwn_url

# %% [markdown]
# ## Adquiriendo BTC_US_fv

# %%
# Se carga la base de datos de BTC_US_fv desde la carpeta compartida en el Google Drive
sharing_url = "https://drive.google.com/file/d/1khOq6X7TVPah5Gh-HHCyEt382MLPINvS/view?usp=sharing"

# %%
dwn_url=gdriveColabPath(sharing_url)
BTC_US_fv_df = pd.read_csv(dwn_url, sep=";", decimal=".")
BTC_US_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0       0
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0       0
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0       0
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0       0
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0       0
#
#    Price_SP500  Price_NASDAQ  Price_DJ  Price_US_Bond  I_Percentage_diff_ACPI  \
# 0      1064.88       2179.05  10097.90          2.954                 1.34078
# 1      1071.25       2198.23  10154.43          2.954                 1.34078
# 2      1083.48       2222.49  10229.96          2.954                 1.34078
# 3      1069.59       2187.33  10120.53          2.954                 1.34078
# 4      1093.67       2245.89  10322.30          2.954                 1.34078
#
#    M_Percentage_diff_MCPI  FEDfunds  Percentage_diff_USD_JPY  Trend  \
# 0                 0.18693      0.18                    -0.98    NaN
# 1                 0.18693      0.18                     0.21    NaN
# 2                 0.18693      0.18                     0.75    NaN
# 3                 0.18693      0.18                    -0.64    0.1
# 4                 0.18693      0.18                     0.43    0.1
#
#    Seasonality  Residuals     BTC_cycle
# 0    -3.979105        NaN -1.869639e-06
# 1     8.917886        NaN -1.538597e-06
# 2     1.150686        NaN -1.206386e-06
# 3    19.575231 -19.575231 -8.708768e-07
# 4   -15.128694  15.128694 -5.291847e-07

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Análisis pre-modelado

# %%
# Registros y columnas
BTC_US_fv_df.shape
# Out:
# (4386, 20)

# %%
# Nombre de columnas
BTC_US_fv_df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff',
#        'Target', 'Price_SP500', 'Price_NASDAQ', 'Price_DJ', 'Price_US_Bond',
#        'I_Percentage_diff_ACPI', 'M_Percentage_diff_MCPI', 'FEDfunds',
#        'Percentage_diff_USD_JPY', 'Trend', 'Seasonality', 'Residuals',
#        'BTC_cycle'],
#       dtype='object')

# %%
# Tipos de datos de las variables
BTC_US_fv_df.dtypes
# Out:
# Date                        object
# Price                      float64
# Open                       float64
# High                       float64
# Low                        float64
# Vol.                       float64
# Percentage_diff            float64
# Target                       int64
# Price_SP500                float64
# Price_NASDAQ               float64
# Price_DJ                   float64
# Price_US_Bond              float64
# I_Percentage_diff_ACPI     float64
# M_Percentage_diff_MCPI     float64
# FEDfunds                   float64
# Percentage_diff_USD_JPY    float64
# Trend                      float64
# Seasonality                float64
# Residuals                  float64
# BTC_cycle                  float64
# dtype: object

# %%
# Columnas y cantidad de registros
BTC_US_fv_df.count()
# Out:
# Date                       4386
# Price                      4386
# Open                       4386
# High                       4386
# Low                        4386
# Vol.                       4386
# Percentage_diff            4386
# Target                     4386
# Price_SP500                4386
# Price_NASDAQ               4386
# Price_DJ                   4386
# Price_US_Bond              4386
# I_Percentage_diff_ACPI     4386
# M_Percentage_diff_MCPI     4386
# FEDfunds                   4386
# Percentage_diff_USD_JPY    4386
# Trend                      4380
# Seasonality                4386
# Residuals                  4380
# BTC_cycle                  4386
# dtype: int64

# %%
# Valores NaN
BTC_US_fv_df.isnull().sum()
# Out:
# Date                       0
# Price                      0
# Open                       0
# High                       0
# Low                        0
# Vol.                       0
# Percentage_diff            0
# Target                     0
# Price_SP500                0
# Price_NASDAQ               0
# Price_DJ                   0
# Price_US_Bond              0
# I_Percentage_diff_ACPI     0
# M_Percentage_diff_MCPI     0
# FEDfunds                   0
# Percentage_diff_USD_JPY    0
# Trend                      6
# Seasonality                0
# Residuals                  6
# BTC_cycle                  0
# dtype: int64

# %%
BTC_US_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0       0
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0       0
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0       0
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0       0
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0       0
#
#    Price_SP500  Price_NASDAQ  Price_DJ  Price_US_Bond  I_Percentage_diff_ACPI  \
# 0      1064.88       2179.05  10097.90          2.954                 1.34078
# 1      1071.25       2198.23  10154.43          2.954                 1.34078
# 2      1083.48       2222.49  10229.96          2.954                 1.34078
# 3      1069.59       2187.33  10120.53          2.954                 1.34078
# 4      1093.67       2245.89  10322.30          2.954                 1.34078
#
#    M_Percentage_diff_MCPI  FEDfunds  Percentage_diff_USD_JPY  Trend  \
# 0                 0.18693      0.18                    -0.98    NaN
# 1                 0.18693      0.18                     0.21    NaN
# 2                 0.18693      0.18                     0.75    NaN
# 3                 0.18693      0.18                    -0.64    0.1
# 4                 0.18693      0.18                     0.43    0.1
#
#    Seasonality  Residuals     BTC_cycle
# 0    -3.979105        NaN -1.869639e-06
# 1     8.917886        NaN -1.538597e-06
# 2     1.150686        NaN -1.206386e-06
# 3    19.575231 -19.575231 -8.708768e-07
# 4   -15.128694  15.128694 -5.291847e-07

# %% [markdown]
# Observaciones:
#
# Se observaron varios registros NaN en "BTC_US_fv.csv".
#
# Esto implica la necesidad de tomar una decisión con respecto a este tipo de valores (instancia previa al modelado).
#
# Se descarta rellenar los NaN con promedios de valores previos y/o posteriores por varias razones:
#
# 1. En las variables [Trend] y [Residuals], 3 de los 6 valores NaN se encuentran al principio de la serie, y los restantes 3 al final de la misma. Esto significa que no se puede hacer un promedio con valores anteriores y posteriores a los valores NaN sino solo con anteriores o posteriores según el caso. Proceder con un promedio con los datos anteriores o posteriores en una serie de tiempo supone un problema extra (¿cuántos valores hacia atrás o hacia adelante se deben tomar?, ¿cuál es el grado de autocorrelación con los valores anteriores o posteriores?, entre otros).
#
#
# 2. En la variable [Residuals] hay valores positivos y negativos en los registros anteriores y posteriores inmediatos según el caso. Esto también añade un problema extra (¿qué signo se debería utilizar si se rellenan esos casilleros?).
#
#
# 3. Al no tratarse de un problema de regresión lineal del valor que tomaría el precio de BTC en el registro siguiente sino un problema de clasificación, la eliminación de los valores NaN no afectaría en demasía la predicción del modelo a pesar de la autocorrelación referida en el punto 2. Si se considera eliminar los 12 registros NaN (6 en [Residual] y 6 en [Trend] ) se estaría solamente eliminando un (6*100/4386 =) 0.136 % de los datos.
#
# Se eliminarán los valores NaN dado que los modelos no los toleran y no impactan en el marco general del proyecto (ver razones aducidas arriba).

# %% [markdown]
# ## Ultimas manipulaciones pre-modelado

# %% [markdown]
# Se reindexa el data set que se modelará a fin de que la variable [Date] funcione como nuevo índice de la base de datos.

# %%
# Se crea una copia de BTC_US_fv_df con nombre BTC_US y se la reindexa con la variable [Date] como nuevo índice
BTC_US = BTC_US_fv_df.set_index("Date")

# %%
BTC_US.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target  Price_SP500  Price_NASDAQ  Price_DJ  Price_US_Bond  \
# Date
# 2022-07-16       1      3863.16      11452.42  31286.02          2.889
# 2022-07-17       0      3863.16      11452.42  31286.02          2.889
# 2022-07-18       1      3830.85      11360.05  31071.75          2.889
# 2022-07-19       1      3936.69      11713.15  31824.71          2.889
# 2022-07-20       0      3936.69      11713.15  31824.71          2.889
#
#             I_Percentage_diff_ACPI  M_Percentage_diff_MCPI  FEDfunds  \
# Date
# 2022-07-16                 8.48213                 -0.0193      1.68
# 2022-07-17                 8.48213                 -0.0193      1.68
# 2022-07-18                 8.48213                 -0.0193      1.68
# 2022-07-19                 8.48213                 -0.0193      1.68
# 2022-07-20                 8.48213                 -0.0193      1.68
#
#             Percentage_diff_USD_JPY         Trend  Seasonality   Residuals  \
# Date
# 2022-07-16                    -0.27  21370.371429    -0.183737 -160.287691
# 2022-07-17                    -0.27  21784.528571    -3.979105 -994.949467
# 2022-07-18                    -0.30           NaN     8.917886         NaN
# 2022-07-19                     0.04           NaN     1.150686         NaN
# 2022-07-20                    -0.08           NaN    19.575231         NaN
#
#               BTC_cycle
# Date
# 2022-07-16  -154.061979
# 2022-07-17  -745.841392
# 2022-07-18   822.393782
# 2022-07-19  1532.500614
# 2022-07-20  1096.422183

# %% [markdown]
# Dado que en la práctica real solo se tiene hasta los valores del registro anterior al que se quiere predecir se intenta hacer un shift (-1) a la variable [Target]. Se entiende que así (en caso de que el modelo prediga con previsibilidad suficiente) se podría estar seguro de que después vendría el valor de [Target] original sin shift (-1).

# %%
# Se genera un back up
BTC_US_2 = BTC_US.copy()

# %%
# Se realiza el shift 
BTC_US_2 ["Target"] = BTC_US ["Target"].shift(-1)

# %%
BTC_US_2.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target  Price_SP500  Price_NASDAQ  Price_DJ  Price_US_Bond  \
# Date
# 2022-07-16     0.0      3863.16      11452.42  31286.02          2.889
# 2022-07-17     1.0      3863.16      11452.42  31286.02          2.889
# 2022-07-18     1.0      3830.85      11360.05  31071.75          2.889
# 2022-07-19     0.0      3936.69      11713.15  31824.71          2.889
# 2022-07-20     NaN      3936.69      11713.15  31824.71          2.889
#
#             I_Percentage_diff_ACPI  M_Percentage_diff_MCPI  FEDfunds  \
# Date
# 2022-07-16                 8.48213                 -0.0193      1.68
# 2022-07-17                 8.48213                 -0.0193      1.68
# 2022-07-18                 8.48213                 -0.0193      1.68
# 2022-07-19                 8.48213                 -0.0193      1.68
# 2022-07-20                 8.48213                 -0.0193      1.68
#
#             Percentage_diff_USD_JPY         Trend  Seasonality   Residuals  \
# Date
# 2022-07-16                    -0.27  21370.371429    -0.183737 -160.287691
# 2022-07-17                    -0.27  21784.528571    -3.979105 -994.949467
# 2022-07-18                    -0.30           NaN     8.917886         NaN
# 2022-07-19                     0.04           NaN     1.150686         NaN
# 2022-07-20                    -0.08           NaN    19.575231         NaN
#
#               BTC_cycle
# Date
# 2022-07-16  -154.061979
# 2022-07-17  -745.841392
# 2022-07-18   822.393782
# 2022-07-19  1532.500614
# 2022-07-20  1096.422183

# %% [markdown]
# Se elimina el registro NaN de la variable [Target] dado que los modelos no pueden procesar este tipo de datos

# %%
BTC_US_2 = BTC_US_2 [0:4385]

# %%
BTC_US_2.isnull().sum()
# Out:
# Price                      0
# Open                       0
# High                       0
# Low                        0
# Vol.                       0
# Percentage_diff            0
# Target                     0
# Price_SP500                0
# Price_NASDAQ               0
# Price_DJ                   0
# Price_US_Bond              0
# I_Percentage_diff_ACPI     0
# M_Percentage_diff_MCPI     0
# FEDfunds                   0
# Percentage_diff_USD_JPY    0
# Trend                      5
# Seasonality                0
# Residuals                  5
# BTC_cycle                  0
# dtype: int64

# %% [markdown]
# Se eliminan los valores NaN del resto de las columnas ([Trend] y [Seasonality])

# %%
BTC_US_2 = BTC_US_2.dropna()

# %%
BTC_US_2.isnull().sum()
# Out:
# Price                      0
# Open                       0
# High                       0
# Low                        0
# Vol.                       0
# Percentage_diff            0
# Target                     0
# Price_SP500                0
# Price_NASDAQ               0
# Price_DJ                   0
# Price_US_Bond              0
# I_Percentage_diff_ACPI     0
# M_Percentage_diff_MCPI     0
# FEDfunds                   0
# Percentage_diff_USD_JPY    0
# Trend                      0
# Seasonality                0
# Residuals                  0
# BTC_cycle                  0
# dtype: int64

# %%
BTC_US_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4380 entries, 2010-07-21 to 2022-07-17
# Data columns (total 19 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Price                    4380 non-null   float64
#  1   Open                     4380 non-null   float64
#  2   High                     4380 non-null   float64
#  3   Low                      4380 non-null   float64
#  4   Vol.                     4380 non-null   float64
#  5   Percentage_diff          4380 non-null   float64
#  6   Target                   4380 non-null   float64
#  7   Price_SP500              4380 non-null   float64
#  8   Price_NASDAQ             4380 non-null   float64
#  9   Price_DJ                 4380 non-null   float64
#  10  Price_US_Bond            4380 non-null   float64
#  11  I_Percentage_diff_ACPI   4380 non-null   float64
#  12  M_Percentage_diff_MCPI   4380 non-null   float64
#  13  FEDfunds                 4380 non-null   float64
#  14  Percentage_diff_USD_JPY  4380 non-null   float64
#  15  Trend                    4380 non-null   float64
#  16  Seasonality              4380 non-null   float64
#  17  Residuals                4380 non-null   float64
#  18  BTC_cycle                4380 non-null   float64
# dtypes: float64(19)
# memory usage: 684.4+ KB

# %% [markdown]
# # Modelado (Random forest)

# %% [markdown]
# **...Recordando que...**
#
# *Objetivo general del proyecto*
#
# I.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) el dinamismo del precio de Bitcoin en el corto plazo, es decir, si el precio de este criptoactivo subirá o bajará en la temporalidad estudiada (1 día).
#
# **...Recordando que...**
#
# *Objetivo específico del proyecto*
#
# III.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) y a corto plazo, el movimiento alcista o bajista del precio de BTC.

# %% [markdown]
# **Explicación**:
#
# En lo que sigue se procederá a realizar varios modelos supervisados de clasificación de tipo "Random forest".
#
# Estos serán configurados con diversos hiperparámetros a fin de encontrar el resultado más óptimo para este data set.
#
# La variable target del modelo es la columna [Target] de BTC_US_2.

# %% [markdown]
# ## Modelo 1

# %%
# Se separa X e y
X = BTC_US_2.drop(["Target"], axis=1)
y = BTC_US_2 ["Target"]

# %%
# Se separa la data en train (70%) y test (30%)
# Se decide aplicar stratify
(X_train, X_test, y_train, y_test) = train_test_split(X, y,
                                        stratify=y,
                                        test_size=0.30,
                                        random_state=11)

# %%
# Se crea el Random forest
model = RandomForestClassifier(random_state=11, n_estimators=200,
                               class_weight="balanced", max_features="log2")

# %%
# Se entrena al Random forest
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        n_estimators=200, random_state=11)

# %%
#Prediccion en Train

y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

# Se busca conocer el grado de prediccion del modelo utilizando el Test
y_test_pred = model.predict(X_test)

# Se calcula el accuracy en Test
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación es:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación es: 0.6971080669710806

# %% [markdown]
# Observaciones:
#
# - Dado que el % de aciertos en el set de entrenamiento es 1.0 y el % de aciertos en el set de evaluación es 69,7, se entiende que hay overfitting. Para corregirlo se intentará modificar algunos hiperparámetros.

# %% [markdown]
# ## Modelo 2

# %%
# Se crea un nuevo Random forest con otros hiperparámetros
model = RandomForestClassifier(random_state=11,
                               n_estimators=100,
                               class_weight="balanced", 
                               max_features="log2")
model.fit(X_train, y_train)

#Prediccion en Train
y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

#Prediccion en Test
y_test_pred = model.predict(X_test) 
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación: 0.69558599695586

# %% [markdown]
# Observaciones:
#
# - Las modificaciones realizadas no generaron una reducción de la diferencia significativa entre el % de aciertos en el set de entrenamiento y el % de aciertos en el set de evaluación. Se utilizará RandomSearchCV a fin de intentar mejor el resultado.

# %% [markdown]
# ## Hyperparameter tuning

# %%
# Se instancia el modelo
random_forest = RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# Se definen los parámetros de búsqueda
params = {'random_state': np.arange(1,10000,10),
    'n_estimators': [100, 200, 500,1000],
    'max_depth': [1,2,3],
    'class_weight':['balanced'], 
    'max_features': ['log2']}

grid_random_forest = RandomizedSearchCV(random_forest, params, scoring = 'neg_mean_absolute_error', n_iter=100, cv=5, verbose=2)

# %%
# Se entrena el modelo
grid_random_forest.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4151; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4151; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4151; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4151; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4151; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4541; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4541; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4541; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4541; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4541; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9411; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9411; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9411; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9411; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9411; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=251; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=251; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=251; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=251; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=251; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1521; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1521; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1521; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1521; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1521; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9471; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9471; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9471; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9471; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9471; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8601; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8601; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8601; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8601; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8601; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4801; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4801; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4801; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4801; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4801; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9381; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9381; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9381; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9381; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9381; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=351; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=351; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=351; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=351; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=351; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4001; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4001; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4001; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4001; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4001; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=821; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=821; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=821; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=821; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=821; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9321; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9321; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9321; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9321; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9321; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8491; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8491; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8491; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8491; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8491; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2891; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2891; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2891; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2891; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2891; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6911; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6911; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6911; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6911; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6911; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4701; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4701; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4701; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4701; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4701; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=3551; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=3551; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=3551; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=3551; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=3551; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2451; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2451; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2451; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2451; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2451; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=91; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=91; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=91; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=91; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=91; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4241; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4241; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4241; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4241; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4241; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9021; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9021; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9021; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9021; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9021; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7731; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7731; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3741; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3741; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3741; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3741; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3741; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1931; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1931; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1931; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1931; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1931; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=381; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=381; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=381; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=381; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=381; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4541; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4541; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4541; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4541; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4541; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5261; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5261; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5261; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5261; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5261; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1391; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1391; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1391; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1391; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1391; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9801; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9801; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9801; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9801; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9801; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2111; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2111; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2111; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2111; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2111; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2011; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2011; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2011; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2011; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2011; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5051; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5051; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5051; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5051; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5051; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9151; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9151; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9151; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9151; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9151; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9271; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9271; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9271; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9271; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9271; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3901; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3901; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3901; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3901; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3901; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=8431; total time=   5.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=8431; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=8431; total time=   4.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=8431; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=8431; total time=   4.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7991; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7991; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7991; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7991; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7991; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7671; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7671; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7671; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7671; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7671; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8091; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8091; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8091; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8091; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8091; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7731; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8431; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8431; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8431; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8431; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8431; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3451; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3451; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3451; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3451; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3451; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3961; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3961; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3961; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3961; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3961; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1951; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1951; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1951; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1951; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1951; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1621; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1621; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1621; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1621; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1621; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2801; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2311; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2311; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2311; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2311; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=2311; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4481; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4481; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4481; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4481; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4481; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7181; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7181; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7181; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7181; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7181; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9621; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9621; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9621; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9621; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9621; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=7791; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=7791; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=7791; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=7791; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=7791; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=9471; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=9471; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=9471; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=9471; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=9471; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1891; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1891; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1891; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1891; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1891; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5601; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5601; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5601; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5601; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5601; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7621; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7621; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7621; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7621; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=7621; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=951; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=951; total time=   3.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=951; total time=   4.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=951; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=951; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5831; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5831; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5831; total time=   3.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5831; total time=   3.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5831; total time=   4.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6321; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6321; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6321; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6321; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6321; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1861; total time=   3.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1861; total time=   4.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1861; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1861; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1861; total time=   5.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9301; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9301; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9301; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9301; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9301; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7971; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7971; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7971; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7971; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7971; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3871; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3871; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3871; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3871; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3871; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1111; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1111; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1111; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1111; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1111; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5951; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5951; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5951; total time=   3.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5951; total time=   3.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=5951; total time=   3.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4041; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4041; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4041; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4041; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4041; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7581; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7581; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7581; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7581; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7581; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4281; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4281; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4281; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4281; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4281; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9311; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9311; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9311; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9311; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9311; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9911; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9911; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9911; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9911; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=9911; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7061; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7061; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7061; total time=   3.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7061; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7061; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8221; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8221; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8221; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8221; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8221; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6371; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6371; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6371; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6371; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6371; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=481; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=481; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=481; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=481; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=481; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3161; total time=   5.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3161; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3161; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3161; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3161; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=4131; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=4131; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=4131; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=4131; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=4131; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6411; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6411; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6411; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6411; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6411; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3681; total time=   4.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3681; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3681; total time=   4.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3681; total time=   3.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3681; total time=   4.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9161; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9161; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9161; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9161; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=9161; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3931; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3931; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3931; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3931; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3931; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6351; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6351; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6351; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6351; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=6351; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5411; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5411; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5411; total time=   4.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5411; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5411; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=431; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=431; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=431; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=8851; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=8851; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=8851; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=8851; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=8851; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=501; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=501; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=501; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=501; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=501; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8851; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8851; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8851; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8851; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8851; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8401; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8401; total time=   3.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8401; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8401; total time=   4.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8401; total time=   3.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8581; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8581; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8581; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8581; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8581; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2841; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2841; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2841; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2841; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2841; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8081; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8081; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8081; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8081; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=8081; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8561; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8561; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8561; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8561; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8561; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=481; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7191; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7191; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7191; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7191; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7191; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4571; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4571; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4571; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4571; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4571; total time=   1.8s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'class_weight': ['balanced'],
#                                         'max_depth': [1, 2, 3],
#                                         'max_features': ['log2'],
#                                         'n_estimators': [100, 200, 500, 1000],
#                                         'random_state': array([   1,   11,   21,   31,   41,   51,   61,   71,   81,   91,  101,
#         111,  121,  131,  141,  151,  161,  171,  181,  191,  201,  211,
#         221,  231,  241,  251,  261,  271,  281,  291,  301,  311,  321,
#         331,  341,  35...
#        9351, 9361, 9371, 9381, 9391, 9401, 9411, 9421, 9431, 9441, 9451,
#        9461, 9471, 9481, 9491, 9501, 9511, 9521, 9531, 9541, 9551, 9561,
#        9571, 9581, 9591, 9601, 9611, 9621, 9631, 9641, 9651, 9661, 9671,
#        9681, 9691, 9701, 9711, 9721, 9731, 9741, 9751, 9761, 9771, 9781,
#        9791, 9801, 9811, 9821, 9831, 9841, 9851, 9861, 9871, 9881, 9891,
#        9901, 9911, 9921, 9931, 9941, 9951, 9961, 9971, 9981, 9991])},
#                    scoring='neg_mean_absolute_error', verbose=2)

# %%
# Se obtiene el mejor modelo
grid_random_forest.best_estimator_
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=3,
#                        max_features='log2', random_state=7621)

# %%
# Predicción de casos nuevos
grid_random_forest.predict(X_train)
grid_random_forest.predict(X_test)
# Out:
# array([0., 0., 1., ..., 0., 1., 1.])

# %%
# Se obtiene la predicción en Train
y_train_pred = grid_random_forest.predict(X_train) 

# Se obtiene la predicción en Test
y_test_pred = grid_random_forest.predict(X_test)

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.6894977168949772
# % de aciertos sobre el set de evaluación: 0.6971080669710806

# %% [markdown]
# Se resolvió el overfitting y mejoró el accuracy

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# Predicciones
predictions = grid_random_forest.predict(X_test)

#Matriz de Confusión
print(confusion_matrix(y_test, predictions))

#Ploteamos la Matriz
plot_confusion_matrix(grid_random_forest, X_test, y_test)
plt.show()
# Out:
# [[472 206]
#  [192 444]]

# %% [markdown]
# Observaciones:
# - Al modelo le cuesta encontrar las clases.

# %%
# Accuracy
print(f"Accuracy of the classifier is: {accuracy_score(y_test, predictions)}")

# Precision
from sklearn.metrics import precision_score
print(f"Precision Score of the classifier is: {precision_score(y_test, predictions)}")

# Recall
from sklearn.metrics import recall_score
print(f"Recall Score of the classifier is: {recall_score(y_test, predictions)}")

# Calculo del F1 score
from sklearn.metrics import f1_score
print(f"F1 Score of the classifier is: {f1_score(y_test, predictions)}")

#Template CURVA - ROC

from sklearn.metrics import roc_curve, auc

class_probabilities = grid_random_forest.predict_proba(X_test)
preds = class_probabilities[:, 1]

fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# AUC
print(f"AUC for our classifier is: {roc_auc}")

# Gráfica de la Curva ROC
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Accuracy of the classifier is: 0.6971080669710806
# Precision Score of the classifier is: 0.683076923076923
# Recall Score of the classifier is: 0.6981132075471698
# F1 Score of the classifier is: 0.6905132192846034
# AUC for our classifier is: 0.7540154635349993

# %% [markdown]
# Observaciones:
# - Es un modelo que le cuesta detectar las clases aunque es uno de los mejores que se encontró hasta el momento.
