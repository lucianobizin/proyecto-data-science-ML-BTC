# %% [markdown]
# # Fecha de entrega: 27/08/2022 (corresponde a clase 20)

# %% [markdown]
# # Algoritmo de clasificación: Random forest

# %% [markdown]
# # Diccionario

# %% [markdown]
# **BTC_ind_mom_ET_fv**
#
# - Date: fecha en YYYY-MM-DD (object)
# - Price: precio de cierre de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Open: precio de apertura de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - High: precio más alto de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Low: precio más bajo de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Vol.: volumen de BTC (Número de intercambios) en el día de la fecha (float) (Variable numérica continua)
# - Percentage_diff: diferencia porcentual del precio de BTC en la fecha [x+1] con respecto a la fecha [x] (float) (Variable numérica continua)
# - Target: 1 indica que en el día de la fecha el precio de BTC subió, y 0 que el precio bajó (float) (Se la tratará como variable categórica)
# - ADX: valores del índice de movimiento direccional medio (float) (Variable numérica continua)
# - ADX_MDI: valores del Corriente Menos Movimiento Direccional (MDI) (float) (Variable numérica continua)
# - ADX_MDM: valores del Mínimo Actual Menos el Mínimo Anterior (-DM) (float) (Variable numérica continua)
# - ADX_DX: valores del índice de movimiento direccional (DX) (float) (Variable numérica continua)
# - ADX_PDI: valores del Corriente Plus Movimiento Direccional (PDM) (float) (Variable numérica continua)
# - ADX_PDM: valores del Máximo Actual Menos el Máximo Anterior (+DM) (float) (Variable numérica continua)
# - Aroon_Oscillator: valores del Oscilador Aroon (float) (Variable numérica continua)
# - MACD: valores del MACD (float) (Variable numérica continua)
# - MACDSIGNAL: valores de la señal de MACD (float) (Variable numérica continua)
# - MACDHIST: valores del histograma del MACD (float) (Variable numérica continua)
# - MOM: valores del indicador Momentum (float) (Variable numérica continua)
# - ROC: valores de la tasa de cambio de una variable durante un período específico de tiempo (float) (Variable numérica continua)
# - RSI: valores del índice de fuerza relativa (float) (Variable numérica continua)
# - STOCHRSI_fastk: valores de la aplicación del método estocástico al indicador RSI (con variable d) (más lento) (float) (Variable numérica continua)
# - ULTOSC: valores del indicador Ultimate Oscillator (float) (Variable numérica continua)
# - WILLR: valores del indicador Williams %R (float) (Variable numérica continua)
# - ADX_ET: valores categóricos de la aplicación de la estrategia ADX (comprar, vender, mantener posición) (object)
# - ADXR_ET: valores categóricos de la aplicación de la estrategia ADXR (comprar, vender, mantener posición) (object)
# - MACD_ET: valores categóricos de la aplicación de la estrategia MACD (comprar, vender, mantener posición) (object)
# - ROC_ET: valores categóricos de la aplicación de la estrategia ROC (comprar, vender, mantener posición) (object)
# - STOCHRSI_fastk_ET: valores categóricos de la aplicación de la estrategia STOCHRSI_fastk (comprar, vender, mantener posición) (object)

# %% [markdown]
# # Librerías

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas_profiling
import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib.cm import ScalarMappable

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor 

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('darkgrid')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Data acquisition

# %%
def gdriveColabPath(sharing_url):
  file_id=sharing_url.split('/')[-2]
  dwn_url='https://drive.google.com/uc?id=' + file_id
  return dwn_url

# %% [markdown]
# ## Adquiriendo BTC_ind_mom_ET_fv

# %%
# Se carga la base de datos de BTC_ind_mom_ET_fv desde la carpeta compartida en el Google Drive
sharing_url = "https://drive.google.com/file/d/1r970fI0CJdhcCX8rt9Ld1pfbw6DjxIiB/view?usp=sharing"

# %%
dwn_url=gdriveColabPath(sharing_url)
BTC_ind_mom_fv_df = pd.read_csv(dwn_url, sep=";", decimal=".")
BTC_ind_mom_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  ADX  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0  NaN
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0  NaN
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0  NaN
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0  NaN
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0  NaN
#
#    ADX_MDI  ADX_MDM  ADX_DX  ADX_PDI  ADX_PDM  Aroon_Oscillator  MACD  \
# 0      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 1      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 2      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 3      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 4      NaN      NaN     NaN      NaN      NaN               NaN   NaN
#
#    MACDSIGNAL  MACDHIST  MOM  ROC  RSI  STOCHRSI_fastk  ULTOSC  WILLR  \
# 0         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 1         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 2         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 3         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 4         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
#
#               ADX_ET            ADXR_ET            MACD_ET             ROC_ET  \
# 0  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 1  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 3  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 4  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#    STOCHRSI_fastk_ET  Trend  Residuals
# 0  Mantener_posicion    NaN        NaN
# 1  Mantener_posicion    NaN        NaN
# 2  Mantener_posicion    NaN        NaN
# 3  Mantener_posicion    0.1 -19.575231
# 4  Mantener_posicion    0.1  15.128694

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Análisis pre-modelado

# %%
# Registros y columnas
BTC_ind_mom_fv_df.shape
# Out:
# (4386, 31)

# %%
# Nombre de columnas
BTC_ind_mom_fv_df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff',
#        'Target', 'ADX', 'ADX_MDI', 'ADX_MDM', 'ADX_DX', 'ADX_PDI', 'ADX_PDM',
#        'Aroon_Oscillator', 'MACD', 'MACDSIGNAL', 'MACDHIST', 'MOM', 'ROC',
#        'RSI', 'STOCHRSI_fastk', 'ULTOSC', 'WILLR', 'ADX_ET', 'ADXR_ET',
#        'MACD_ET', 'ROC_ET', 'STOCHRSI_fastk_ET', 'Trend', 'Residuals'],
#       dtype='object')

# %%
# Tipos de datos de las variables
BTC_ind_mom_fv_df.dtypes
# Out:
# Date                  object
# Price                float64
# Open                 float64
# High                 float64
# Low                  float64
# Vol.                 float64
# Percentage_diff      float64
# Target               float64
# ADX                  float64
# ADX_MDI              float64
# ADX_MDM              float64
# ADX_DX               float64
# ADX_PDI              float64
# ADX_PDM              float64
# Aroon_Oscillator     float64
# MACD                 float64
# MACDSIGNAL           float64
# MACDHIST             float64
# MOM                  float64
# ROC                  float64
# RSI                  float64
# STOCHRSI_fastk       float64
# ULTOSC               float64
# WILLR                float64
# ADX_ET                object
# ADXR_ET               object
# MACD_ET               object
# ROC_ET                object
# STOCHRSI_fastk_ET     object
# Trend                float64
# Residuals            float64
# dtype: object

# %%
# Columnas y cantidad de registros
BTC_ind_mom_fv_df.count()
# Out:
# Date                 4386
# Price                4386
# Open                 4386
# High                 4386
# Low                  4386
# Vol.                 4386
# Percentage_diff      4386
# Target               4386
# ADX                  4359
# ADX_MDI              4372
# ADX_MDM              4372
# ADX_DX               4372
# ADX_PDI              4372
# ADX_PDM              4373
# Aroon_Oscillator     4372
# MACD                 4353
# MACDSIGNAL           4353
# MACDHIST             4353
# MOM                  4376
# ROC                  4376
# RSI                  4376
# STOCHRSI_fastk       4366
# ULTOSC               4358
# WILLR                4373
# ADX_ET               4386
# ADXR_ET              4386
# MACD_ET              4386
# ROC_ET               4386
# STOCHRSI_fastk_ET    4386
# Trend                4380
# Residuals            4380
# dtype: int64

# %%
# Valores NaN
BTC_ind_mom_fv_df.isnull().sum()
# Out:
# Date                  0
# Price                 0
# Open                  0
# High                  0
# Low                   0
# Vol.                  0
# Percentage_diff       0
# Target                0
# ADX                  27
# ADX_MDI              14
# ADX_MDM              14
# ADX_DX               14
# ADX_PDI              14
# ADX_PDM              13
# Aroon_Oscillator     14
# MACD                 33
# MACDSIGNAL           33
# MACDHIST             33
# MOM                  10
# ROC                  10
# RSI                  10
# STOCHRSI_fastk       20
# ULTOSC               28
# WILLR                13
# ADX_ET                0
# ADXR_ET               0
# MACD_ET               0
# ROC_ET                0
# STOCHRSI_fastk_ET     0
# Trend                 6
# Residuals             6
# dtype: int64

# %%
BTC_ind_mom_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  ADX  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0  NaN
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0  NaN
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0  NaN
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0  NaN
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0  NaN
#
#    ADX_MDI  ADX_MDM  ADX_DX  ADX_PDI  ADX_PDM  Aroon_Oscillator  MACD  \
# 0      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 1      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 2      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 3      NaN      NaN     NaN      NaN      NaN               NaN   NaN
# 4      NaN      NaN     NaN      NaN      NaN               NaN   NaN
#
#    MACDSIGNAL  MACDHIST  MOM  ROC  RSI  STOCHRSI_fastk  ULTOSC  WILLR  \
# 0         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 1         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 2         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 3         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
# 4         NaN       NaN  NaN  NaN  NaN             NaN     NaN    NaN
#
#               ADX_ET            ADXR_ET            MACD_ET             ROC_ET  \
# 0  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 1  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 3  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 4  Mantener_posicion  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#    STOCHRSI_fastk_ET  Trend  Residuals
# 0  Mantener_posicion    NaN        NaN
# 1  Mantener_posicion    NaN        NaN
# 2  Mantener_posicion    NaN        NaN
# 3  Mantener_posicion    0.1 -19.575231
# 4  Mantener_posicion    0.1  15.128694

# %% [markdown]
# Observaciones:
#
# Se observaron varios registros NaN en "BTC_ind_mom_ET_fv.csv".
#
# Esto implica la necesidad de tomar una decisión con respecto a este tipo de valores (instancia previa al modelado).
#
# Se descarta rellenar los NaN con promedios de valores previos y/o posteriores por varias razones:
#
# 1. En las variables [Trend] y [Residuals], 3 de los 6 valores NaN se encuentran al principio de la serie, y los restantes 3 al final de la misma. Esto significa que no se puede hacer un promedio con valores anteriores y posteriores a los valores NaN sino solo con anteriores o posteriores según el caso. Proceder con un promedio con los datos anteriores o posteriores en una serie de tiempo supone un problema extra (¿cuántos valores hacia atrás o hacia adelante se deben tomar?, ¿cuál es el grado de autocorrelación con los valores anteriores o posteriores?, entre otros).
#
#
# 2. En la variable [Residuals] hay valores positivos y negativos en los registros anteriores y posteriores inmediatos según el caso. Esto también añade un problema extra (¿qué signo se debería utilizar si se rellenan esos casilleros?).
#
#
# 3. Al no tratarse de un problema de regresión lineal del valor que tomaría el precio de BTC en el registro siguiente sino un problema de clasificación, la eliminación de los valores NaN no afectaría en demasía la predicción del modelo a pesar de la autocorrelación referida en el punto 2. Si se considera eliminar los 33 registros NaN (variable -> MACD) se estaría solamente eliminando un (33*100/4386 =) 0.75 % de los datos.
#
# Se eliminarán los valores NaN dado que los modelos no los toleran y no impactan en el marco general del proyecto (ver razones aducidas arriba).

# %% [markdown]
# ## Ultimas manipulaciones pre-modelado

# %% [markdown]
# Se reindexa el data set que se modelará a fin de que la variable [Date] funcione como nuevo índice de la base de datos.

# %%
# Se crea una copia de BTC_ind_mom_fv_df con nombre BTC_ind_mom y se la reindexa con la variable [Date] como nuevo índice
BTC_ind_mom = BTC_ind_mom_fv_df.set_index("Date")

# %%
BTC_ind_mom.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target        ADX    ADX_MDI    ADX_MDM     ADX_DX    ADX_PDI  \
# Date
# 2022-07-16     1.0  27.268083  24.194644  24.194644   6.885001  21.077646
# 2022-07-17     0.0  25.710035  22.840734  22.840734   5.455418  20.477541
# 2022-07-18     1.0  24.545625  20.207578  20.207578   9.408284  24.404841
# 2022-07-19     1.0  24.304487  17.742843  17.742843  21.169702  27.272446
# 2022-07-20     0.0  24.080574  17.259314  17.259314  21.169702  26.529215
#
#                 ADX_PDM  Aroon_Oscillator        MACD  MACDSIGNAL    MACDHIST  \
# Date
# 2022-07-16  3443.366972         35.714286 -636.592931 -960.502376  323.909445
# 2022-07-17  3290.512188         35.714286 -577.232483 -883.848398  306.615914
# 2022-07-18  4115.975603         35.714286 -385.327489 -784.144216  398.816727
# 2022-07-19  4864.377346         42.857143 -160.032949 -659.321963  499.289013
# 2022-07-20  4516.921821         42.857143   -2.524886 -527.962547  525.437661
#
#                MOM       ROC        RSI  STOCHRSI_fastk     ULTOSC      WILLR  \
# Date
# 2022-07-16   648.8  0.031555  54.341002      100.000000  55.402532 -34.498468
# 2022-07-17  -852.2 -0.039385  49.615550       59.412565  52.658819 -47.925083
# 2022-07-18   914.6  0.042321  63.915158      100.000000  61.793596  -5.012325
# 2022-07-19  1822.7  0.084433  68.899442      100.000000  68.346203  -7.208573
# 2022-07-20  2301.7  0.110407  65.912930       87.564957  64.588452 -12.631098
#
#                        ADX_ET            ADXR_ET            MACD_ET  \
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-17  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-18            Comprar  Mantener_posicion  Mantener_posicion
# 2022-07-19  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-20  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                        ROC_ET  STOCHRSI_fastk_ET         Trend   Residuals
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  21370.371429 -160.287691
# 2022-07-17             Vender             Vender  21784.528571 -994.949467
# 2022-07-18            Comprar            Comprar           NaN         NaN
# 2022-07-19  Mantener_posicion  Mantener_posicion           NaN         NaN
# 2022-07-20  Mantener_posicion  Mantener_posicion           NaN         NaN

# %% [markdown]
# Dado que en la práctica real solo se tiene hasta los valores del registro anterior al que se quiere predecir se intenta hacer un shift (-1) a la variable [Target]. Se entiende que así (en caso de que el modelo prediga con previsibilidad suficiente) se podría estar seguro de que después vendría el valor de [Target] original sin shift (-1).

# %%
# Se genera un back up
BTC_ind_mom_2 = BTC_ind_mom.copy()

# %%
# Se realiza el shift 
BTC_ind_mom_2 ["Target"] = BTC_ind_mom ["Target"].shift(-1)

# %%
BTC_ind_mom_2.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target        ADX    ADX_MDI    ADX_MDM     ADX_DX    ADX_PDI  \
# Date
# 2022-07-16     0.0  27.268083  24.194644  24.194644   6.885001  21.077646
# 2022-07-17     1.0  25.710035  22.840734  22.840734   5.455418  20.477541
# 2022-07-18     1.0  24.545625  20.207578  20.207578   9.408284  24.404841
# 2022-07-19     0.0  24.304487  17.742843  17.742843  21.169702  27.272446
# 2022-07-20     NaN  24.080574  17.259314  17.259314  21.169702  26.529215
#
#                 ADX_PDM  Aroon_Oscillator        MACD  MACDSIGNAL    MACDHIST  \
# Date
# 2022-07-16  3443.366972         35.714286 -636.592931 -960.502376  323.909445
# 2022-07-17  3290.512188         35.714286 -577.232483 -883.848398  306.615914
# 2022-07-18  4115.975603         35.714286 -385.327489 -784.144216  398.816727
# 2022-07-19  4864.377346         42.857143 -160.032949 -659.321963  499.289013
# 2022-07-20  4516.921821         42.857143   -2.524886 -527.962547  525.437661
#
#                MOM       ROC        RSI  STOCHRSI_fastk     ULTOSC      WILLR  \
# Date
# 2022-07-16   648.8  0.031555  54.341002      100.000000  55.402532 -34.498468
# 2022-07-17  -852.2 -0.039385  49.615550       59.412565  52.658819 -47.925083
# 2022-07-18   914.6  0.042321  63.915158      100.000000  61.793596  -5.012325
# 2022-07-19  1822.7  0.084433  68.899442      100.000000  68.346203  -7.208573
# 2022-07-20  2301.7  0.110407  65.912930       87.564957  64.588452 -12.631098
#
#                        ADX_ET            ADXR_ET            MACD_ET  \
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-17  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-18            Comprar  Mantener_posicion  Mantener_posicion
# 2022-07-19  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-20  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                        ROC_ET  STOCHRSI_fastk_ET         Trend   Residuals
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  21370.371429 -160.287691
# 2022-07-17             Vender             Vender  21784.528571 -994.949467
# 2022-07-18            Comprar            Comprar           NaN         NaN
# 2022-07-19  Mantener_posicion  Mantener_posicion           NaN         NaN
# 2022-07-20  Mantener_posicion  Mantener_posicion           NaN         NaN

# %% [markdown]
# Se convierten las variables categóricas ([ADX_ET], [ADXR_ET], [MACD_ET], [ROC_ET], [STOCHRSI_fastk_ET]) en variables dummies y se agregan a BTC_ind_mom_2

# %%
Variables = ["ADX_ET", "ADXR_ET", "MACD_ET", "ROC_ET", "STOCHRSI_fastk_ET"]

for var in Variables:
    dummies = pd.get_dummies(BTC_ind_mom_2 [var])
    dummies = dummies.rename(columns={"Comprar":"Comprar_"+var+"", "Mantener_posicion":"Mantener_posicion_"+var+"", "Vender":"Vender_"+var+""})
    BTC_ind_mom_2 = pd.concat([BTC_ind_mom_2, dummies], axis = 1)

# %%
BTC_ind_mom_2.head()
# Out:
#             Price  Open  High  Low    Vol.  Percentage_diff  Target  ADX  \
# Date
# 2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0  NaN
# 2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0  NaN
# 2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0  NaN
# 2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0  NaN
# 2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0  NaN
#
#             ADX_MDI  ADX_MDM  ADX_DX  ADX_PDI  ADX_PDM  Aroon_Oscillator  \
# Date
# 2010-07-18      NaN      NaN     NaN      NaN      NaN               NaN
# 2010-07-19      NaN      NaN     NaN      NaN      NaN               NaN
# 2010-07-20      NaN      NaN     NaN      NaN      NaN               NaN
# 2010-07-21      NaN      NaN     NaN      NaN      NaN               NaN
# 2010-07-22      NaN      NaN     NaN      NaN      NaN               NaN
#
#             MACD  MACDSIGNAL  MACDHIST  MOM  ROC  RSI  STOCHRSI_fastk  ULTOSC  \
# Date
# 2010-07-18   NaN         NaN       NaN  NaN  NaN  NaN             NaN     NaN
# 2010-07-19   NaN         NaN       NaN  NaN  NaN  NaN             NaN     NaN
# 2010-07-20   NaN         NaN       NaN  NaN  NaN  NaN             NaN     NaN
# 2010-07-21   NaN         NaN       NaN  NaN  NaN  NaN             NaN     NaN
# 2010-07-22   NaN         NaN       NaN  NaN  NaN  NaN             NaN     NaN
#
#             WILLR             ADX_ET            ADXR_ET            MACD_ET  \
# Date
# 2010-07-18    NaN  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2010-07-19    NaN  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2010-07-20    NaN  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2010-07-21    NaN  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2010-07-22    NaN  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                        ROC_ET  STOCHRSI_fastk_ET  Trend  Residuals  \
# Date
# 2010-07-18  Mantener_posicion  Mantener_posicion    NaN        NaN
# 2010-07-19  Mantener_posicion  Mantener_posicion    NaN        NaN
# 2010-07-20  Mantener_posicion  Mantener_posicion    NaN        NaN
# 2010-07-21  Mantener_posicion  Mantener_posicion    0.1 -19.575231
# 2010-07-22  Mantener_posicion  Mantener_posicion    0.1  15.128694
#
#             Comprar_ADX_ET  Mantener_posicion_ADX_ET  Vender_ADX_ET  \
# Date
# 2010-07-18               0                         1              0
# 2010-07-19               0                         1              0
# 2010-07-20               0                         1              0
# 2010-07-21               0                         1              0
# 2010-07-22               0                         1              0
#
#             Comprar_ADXR_ET  Mantener_posicion_ADXR_ET  Vender_ADXR_ET  \
# Date
# 2010-07-18                0                          1               0
# 2010-07-19                0                          1               0
# 2010-07-20                0                          1               0
# 2010-07-21                0                          1               0
# 2010-07-22                0                          1               0
#
#             Comprar_MACD_ET  Mantener_posicion_MACD_ET  Vender_MACD_ET  \
# Date
# 2010-07-18                0                          1               0
# 2010-07-19                0                          1               0
# 2010-07-20                0                          1               0
# 2010-07-21                0                          1               0
# 2010-07-22                0                          1               0
#
#             Comprar_ROC_ET  Mantener_posicion_ROC_ET  Vender_ROC_ET  \
# Date
# 2010-07-18               0                         1              0
# 2010-07-19               0                         1              0
# 2010-07-20               0                         1              0
# 2010-07-21               0                         1              0
# 2010-07-22               0                         1              0
#
#             Comprar_STOCHRSI_fastk_ET  Mantener_posicion_STOCHRSI_fastk_ET  \
# Date
# 2010-07-18                          0                                    1
# 2010-07-19                          0                                    1
# 2010-07-20                          0                                    1
# 2010-07-21                          0                                    1
# 2010-07-22                          0                                    1
#
#             Vender_STOCHRSI_fastk_ET
# Date
# 2010-07-18                         0
# 2010-07-19                         0
# 2010-07-20                         0
# 2010-07-21                         0
# 2010-07-22                         0

# %% [markdown]
# Se eliminan las variables categóricas del BTC_ind_mom_2

# %%
BTC_ind_mom_2 = BTC_ind_mom_2.drop(["ADX_ET", "ADXR_ET", "MACD_ET", "ROC_ET", "STOCHRSI_fastk_ET"], axis=1)

# %%
BTC_ind_mom_2.columns
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff', 'Target',
#        'ADX', 'ADX_MDI', 'ADX_MDM', 'ADX_DX', 'ADX_PDI', 'ADX_PDM',
#        'Aroon_Oscillator', 'MACD', 'MACDSIGNAL', 'MACDHIST', 'MOM', 'ROC',
#        'RSI', 'STOCHRSI_fastk', 'ULTOSC', 'WILLR', 'Trend', 'Residuals',
#        'Comprar_ADX_ET', 'Mantener_posicion_ADX_ET', 'Vender_ADX_ET',
#        'Comprar_ADXR_ET', 'Mantener_posicion_ADXR_ET', 'Vender_ADXR_ET',
#        'Comprar_MACD_ET', 'Mantener_posicion_MACD_ET', 'Vender_MACD_ET',
#        'Comprar_ROC_ET', 'Mantener_posicion_ROC_ET', 'Vender_ROC_ET',
#        'Comprar_STOCHRSI_fastk_ET', 'Mantener_posicion_STOCHRSI_fastk_ET',
#        'Vender_STOCHRSI_fastk_ET'],
#       dtype='object')

# %% [markdown]
# Se elimina el registro NaN de la variable [Target] dado que los modelos no pueden procesar este tipo de datos

# %%
BTC_ind_mom_2 = BTC_ind_mom_2 [0:4385]

# %%
BTC_ind_mom_2.isnull().sum()
# Out:
# Price                                   0
# Open                                    0
# High                                    0
# Low                                     0
# Vol.                                    0
# Percentage_diff                         0
# Target                                  0
# ADX                                    27
# ADX_MDI                                14
# ADX_MDM                                14
# ADX_DX                                 14
# ADX_PDI                                14
# ADX_PDM                                13
# Aroon_Oscillator                       14
# MACD                                   33
# MACDSIGNAL                             33
# MACDHIST                               33
# MOM                                    10
# ROC                                    10
# RSI                                    10
# STOCHRSI_fastk                         20
# ULTOSC                                 28
# WILLR                                  13
# Trend                                   5
# Residuals                               5
# Comprar_ADX_ET                          0
# Mantener_posicion_ADX_ET                0
# Vender_ADX_ET                           0
# Comprar_ADXR_ET                         0
# Mantener_posicion_ADXR_ET               0
# Vender_ADXR_ET                          0
# Comprar_MACD_ET                         0
# Mantener_posicion_MACD_ET               0
# Vender_MACD_ET                          0
# Comprar_ROC_ET                          0
# Mantener_posicion_ROC_ET                0
# Vender_ROC_ET                           0
# Comprar_STOCHRSI_fastk_ET               0
# Mantener_posicion_STOCHRSI_fastk_ET     0
# Vender_STOCHRSI_fastk_ET                0
# dtype: int64

# %%
BTC_ind_mom_2 = BTC_ind_mom_2.dropna()

# %%
BTC_ind_mom_2.isnull().sum()
# Out:
# Price                                  0
# Open                                   0
# High                                   0
# Low                                    0
# Vol.                                   0
# Percentage_diff                        0
# Target                                 0
# ADX                                    0
# ADX_MDI                                0
# ADX_MDM                                0
# ADX_DX                                 0
# ADX_PDI                                0
# ADX_PDM                                0
# Aroon_Oscillator                       0
# MACD                                   0
# MACDSIGNAL                             0
# MACDHIST                               0
# MOM                                    0
# ROC                                    0
# RSI                                    0
# STOCHRSI_fastk                         0
# ULTOSC                                 0
# WILLR                                  0
# Trend                                  0
# Residuals                              0
# Comprar_ADX_ET                         0
# Mantener_posicion_ADX_ET               0
# Vender_ADX_ET                          0
# Comprar_ADXR_ET                        0
# Mantener_posicion_ADXR_ET              0
# Vender_ADXR_ET                         0
# Comprar_MACD_ET                        0
# Mantener_posicion_MACD_ET              0
# Vender_MACD_ET                         0
# Comprar_ROC_ET                         0
# Mantener_posicion_ROC_ET               0
# Vender_ROC_ET                          0
# Comprar_STOCHRSI_fastk_ET              0
# Mantener_posicion_STOCHRSI_fastk_ET    0
# Vender_STOCHRSI_fastk_ET               0
# dtype: int64

# %%
BTC_ind_mom_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4350 entries, 2010-08-20 to 2022-07-17
# Data columns (total 40 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Price                                4350 non-null   float64
#  1   Open                                 4350 non-null   float64
#  2   High                                 4350 non-null   float64
#  3   Low                                  4350 non-null   float64
#  4   Vol.                                 4350 non-null   float64
#  5   Percentage_diff                      4350 non-null   float64
#  6   Target                               4350 non-null   float64
#  7   ADX                                  4350 non-null   float64
#  8   ADX_MDI                              4350 non-null   float64
#  9   ADX_MDM                              4350 non-null   float64
#  10  ADX_DX                               4350 non-null   float64
#  11  ADX_PDI                              4350 non-null   float64
#  12  ADX_PDM                              4350 non-null   float64
#  13  Aroon_Oscillator                     4350 non-null   float64
#  14  MACD                                 4350 non-null   float64
#  15  MACDSIGNAL                           4350 non-null   float64
#  16  MACDHIST                             4350 non-null   float64
#  17  MOM                                  4350 non-null   float64
#  18  ROC                                  4350 non-null   float64
#  19  RSI                                  4350 non-null   float64
#  20  STOCHRSI_fastk                       4350 non-null   float64
#  21  ULTOSC                               4350 non-null   float64
#  22  WILLR                                4350 non-null   float64
#  23  Trend                                4350 non-null   float64
#  24  Residuals                            4350 non-null   float64
#  25  Comprar_ADX_ET                       4350 non-null   uint8
#  26  Mantener_posicion_ADX_ET             4350 non-null   uint8
#  27  Vender_ADX_ET                        4350 non-null   uint8
#  28  Comprar_ADXR_ET                      4350 non-null   uint8
#  29  Mantener_posicion_ADXR_ET            4350 non-null   uint8
#  30  Vender_ADXR_ET                       4350 non-null   uint8
#  31  Comprar_MACD_ET                      4350 non-null   uint8
#  32  Mantener_posicion_MACD_ET            4350 non-null   uint8
#  33  Vender_MACD_ET                       4350 non-null   uint8
#  34  Comprar_ROC_ET                       4350 non-null   uint8
#  35  Mantener_posicion_ROC_ET             4350 non-null   uint8
#  36  Vender_ROC_ET                        4350 non-null   uint8
#  37  Comprar_STOCHRSI_fastk_ET            4350 non-null   uint8
#  38  Mantener_posicion_STOCHRSI_fastk_ET  4350 non-null   uint8
#  39  Vender_STOCHRSI_fastk_ET             4350 non-null   uint8
# dtypes: float64(25), uint8(15)
# memory usage: 947.3+ KB

# %% [markdown]
# # Modelado (Random forest)

# %% [markdown]
# **...Recordando que...**
#
# *Objetivo general del proyecto*
#
# I.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) el dinamismo del precio de Bitcoin en el corto plazo, es decir, si el precio de este criptoactivo subirá o bajará en la temporalidad estudiada (1 día).
#
# **...Recordando que...**
#
# *Objetivo específico del proyecto*
#
# III.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) y a corto plazo, el movimiento alcista o bajista del precio de BTC.

# %% [markdown]
# **Explicación**:
#
# En lo que sigue se procederá a realizar varios modelos supervisados de clasificación de tipo "Random forest".
#
# Estos serán configurados con diversos hiperparámetros a fin de encontrar el resultado más óptimo para este data set.
#
# La variable target del modelo es la columna [Target] de BTC_ind_mom_2.

# %% [markdown]
# ## Modelo 1

# %%
# Se separa X e y
X = BTC_ind_mom_2.drop(["Target"], axis=1)
y = BTC_ind_mom_2["Target"]

# %%
# Se separa la data en train (70%) y test (30%)
# Se decide aplicar stratify
(X_train, X_test, y_train, y_test) = train_test_split(X, y,
                                        stratify=y,
                                        test_size=0.30,
                                        random_state=11)

# %%
# Se crea el Random forest
model = RandomForestClassifier(random_state=11, n_estimators=200,
                               class_weight="balanced", max_features="log2")

# %%
# Se entrena al Random forest
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        n_estimators=200, random_state=11)

# %%
#Prediccion en Train

y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

# Se busca conocer el grado de prediccion del modelo utilizando el Test
y_test_pred = model.predict(X_test)

# Se calcula el accuracy en Test
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación es:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación es: 0.6689655172413793

# %% [markdown]
# Observaciones:
#
# - Dado que el % de aciertos en el set de entrenamiento es 100 y el % de aciertos en el set de evaluación es de 67 se entiende que hay overfitting. Para corregirlo se intentará modificar algunos hiperparámetros.

# %% [markdown]
# ## Modelo 2

# %%
# Se crea un nuevo Random forest con otros hiperparámetros
model = RandomForestClassifier(random_state=11,
                               n_estimators=100,
                               class_weight="balanced", 
                               max_features="log2")
model.fit(X_train, y_train)

#Prediccion en Train
y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

#Prediccion en Test
y_test_pred = model.predict(X_test) 
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación: 0.671264367816092

# %% [markdown]
# Observaciones:
#
# - Las modificaciones realizadas no generaron una reducción de la diferencia significativa entre el % de aciertos en el set de entrenamiento y el % de aciertos en el set de evaluación. Se utilizará RandomizedSearchCV a fin de intentar mejor el resultado.

# %% [markdown]
# ## Hyperparameter tuning

# %%
# Se instancia el modelo
random_forest = RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# Se definen los parámetros de búsqueda
params = {'random_state': np.arange(1,10000,10),
    'n_estimators': [100, 200, 500,1000],
    'max_depth': [1,2,3],
    'class_weight':['balanced'], 
    'max_features': ['log2']}

grid_random_forest = RandomizedSearchCV(random_forest, params, scoring = 'neg_mean_absolute_error', n_iter=100, cv=5, verbose=2)

# %%
# Se entrena el modelo
grid_random_forest.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=601; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=601; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=601; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=601; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=601; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5501; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5501; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5501; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5501; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5501; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7211; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7211; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7211; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7211; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7211; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1791; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1791; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1791; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1791; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1791; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2731; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2731; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2731; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2731; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2731; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5861; total time=   0.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5861; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5861; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5861; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5861; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2931; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2931; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2931; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2931; total time=   2.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2931; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9891; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9891; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9891; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9891; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9891; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2881; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2881; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2881; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2881; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2881; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9161; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9161; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9161; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9161; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=9161; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7721; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7721; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7721; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7721; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7721; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=1921; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=1921; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=1921; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=1921; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=1921; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1101; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1101; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1101; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1101; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=1101; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4611; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4611; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4611; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4611; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4611; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7561; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7561; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7561; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7561; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7561; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1281; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1281; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1281; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1281; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=1281; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2561; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2561; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2561; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2561; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2561; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7941; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7941; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7941; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7941; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7941; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7261; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7261; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7261; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7261; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=7261; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=6581; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=6581; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=6581; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=6581; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=6581; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3161; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4431; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4431; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4431; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4431; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=4431; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3251; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3251; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3251; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3251; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3251; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6071; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6071; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6071; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6071; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=6071; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=5061; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=5061; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=5061; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=5061; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=5061; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5211; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5211; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5211; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5211; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5211; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7191; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7191; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7191; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7191; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7191; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=891; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=891; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=891; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=891; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=891; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=921; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=921; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=921; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=921; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=921; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9561; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9561; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9561; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9561; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9561; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8361; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8361; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8361; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8361; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8361; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4741; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4741; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4741; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4741; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4741; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4441; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4441; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4441; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4441; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4441; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4381; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4381; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4381; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4381; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4381; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2461; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2461; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2461; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2461; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2461; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=5851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=5851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=5851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=5851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=5851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2781; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2781; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2781; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2781; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=2781; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4661; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4661; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4661; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4661; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4661; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8111; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8111; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8111; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8111; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8111; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7251; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7251; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7251; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7251; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7251; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=281; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=281; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=281; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=281; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=281; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6921; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6921; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6921; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6921; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=6921; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5971; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5971; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5971; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5971; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=5971; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3181; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3181; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3181; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3181; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3181; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4531; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4531; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4531; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4531; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4531; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5981; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5981; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5981; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5981; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5981; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7081; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7081; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7081; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7081; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=7081; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=2161; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2691; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2691; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2691; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2691; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=2691; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2411; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2411; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2411; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2411; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2411; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2081; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2081; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2081; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2081; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2081; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9961; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9961; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9961; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9961; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=9961; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=771; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=771; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=771; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=771; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=771; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6111; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6111; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6111; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6111; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6111; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=3801; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=3801; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=3801; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=3801; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=3801; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6351; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6351; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6351; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6351; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6351; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3591; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3591; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3591; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3591; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3591; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=2651; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=2651; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=2651; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=2651; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=2651; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5431; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5431; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5431; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5431; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=5431; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2171; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2171; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2171; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2171; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2171; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6931; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6931; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6931; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6931; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6931; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3701; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3701; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3701; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3701; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3701; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2251; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2251; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2251; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2251; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2251; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2621; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2621; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2621; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2621; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2621; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2931; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2931; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2931; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2931; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2931; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2081; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2081; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2081; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2081; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2081; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1121; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1121; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1121; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1121; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1121; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=631; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=631; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=631; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=631; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=631; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3481; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3481; total time=   3.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3481; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3481; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3481; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4131; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=4131; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=2241; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=2241; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=2241; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=2241; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=2241; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9021; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9021; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9021; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9021; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=9021; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=3051; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=3051; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=3051; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=3051; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=3051; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=6141; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=6141; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=6141; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=6141; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=6141; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5111; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5111; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5111; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5111; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=5111; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=191; total time=   1.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=191; total time=   1.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=191; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=191; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=191; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5361; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5361; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5361; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5361; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=5361; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4991; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3151; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3151; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3151; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3151; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=3151; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1131; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1131; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3191; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3191; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3191; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3191; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3191; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2031; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2031; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2031; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2031; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2031; total time=   0.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=4221; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=4221; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=4221; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=4221; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=4221; total time=   3.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7541; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7541; total time=   3.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7541; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7541; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=7541; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9301; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9301; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9301; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9301; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9301; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6461; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6461; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6461; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6461; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=6461; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1901; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1901; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1901; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1901; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1901; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3951; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3951; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3951; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3951; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3951; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9121; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9121; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9121; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9121; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9121; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8421; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8421; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8421; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8421; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8421; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=1491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=1491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=1491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=1491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=1491; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1391; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1391; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=1391; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=9811; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=9811; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=9811; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=9811; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=9811; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1521; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1521; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1521; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1521; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1521; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=7511; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=7511; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=7511; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=7511; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=7511; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1871; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1871; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1871; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1871; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=1871; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6281; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6281; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6281; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6281; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=6281; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2431; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2431; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2431; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2431; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2431; total time=   0.5s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'class_weight': ['balanced'],
#                                         'max_depth': [1, 2, 3],
#                                         'max_features': ['log2'],
#                                         'n_estimators': [100, 200, 500, 1000],
#                                         'random_state': array([   1,   11,   21,   31,   41,   51,   61,   71,   81,   91,  101,
#         111,  121,  131,  141,  151,  161,  171,  181,  191,  201,  211,
#         221,  231,  241,  251,  261,  271,  281,  291,  301,  311,  321,
#         331,  341,  35...
#        9351, 9361, 9371, 9381, 9391, 9401, 9411, 9421, 9431, 9441, 9451,
#        9461, 9471, 9481, 9491, 9501, 9511, 9521, 9531, 9541, 9551, 9561,
#        9571, 9581, 9591, 9601, 9611, 9621, 9631, 9641, 9651, 9661, 9671,
#        9681, 9691, 9701, 9711, 9721, 9731, 9741, 9751, 9761, 9771, 9781,
#        9791, 9801, 9811, 9821, 9831, 9841, 9851, 9861, 9871, 9881, 9891,
#        9901, 9911, 9921, 9931, 9941, 9951, 9961, 9971, 9981, 9991])},
#                    scoring='neg_mean_absolute_error', verbose=2)

# %%
# Se obtiene el mejor modelo
grid_random_forest.best_estimator_
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=2,
#                        max_features='log2', random_state=7941)

# %%
# Se obtiene la predicción en Train
y_train_pred = grid_random_forest.predict(X_train) 

# Se obtiene la predicción en Test
y_test_pred = grid_random_forest.predict(X_test)

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.6614121510673234
# % de aciertos sobre el set de evaluación: 0.6574712643678161

# %% [markdown]
# Observación:
#
# - El Random Forest mejoró el overfitting anterior.
# - En el mejor de los casos se obtuvo 65,7% de aciertos de valores futuros.

# %%
# Se crea un nuevo Random forest con otros hiperparámetros (se agrega balanced a los datos del mejor modelos anterior)
model = RandomForestClassifier(random_state=7941,
                               n_estimators=300,
                               class_weight="balanced", 
                               max_features="log2",
                               max_depth=2)
model.fit(X_train, y_train)

#Prediccion en Train
y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

#Prediccion en Test
y_test_pred = model.predict(X_test) 
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.6571428571428571
# % de aciertos sobre el set de evaluación: 0.660536398467433

# %% [markdown]
# Observaciones:
# - El balance resolvió el overfitting pero no la capacidad de predicción del modelo (67%)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# Predicciones
predictions = model.predict(X_test)

#Matriz de Confusión
print(confusion_matrix(y_test, predictions))

#Ploteamos la Matriz
plot_confusion_matrix(model, X_test, y_test)
plt.show()
# Out:
# [[386 283]
#  [160 476]]

# %% [markdown]
# Observaciones:
# - Al modelo le cuesta encontrar las clases.

# %%
# Accuracy
print(f"Accuracy of the classifier is: {accuracy_score(y_test, predictions)}")

# Precision
from sklearn.metrics import precision_score
print(f"Precision Score of the classifier is: {precision_score(y_test, predictions)}")

# Recall
from sklearn.metrics import recall_score
print(f"Recall Score of the classifier is: {recall_score(y_test, predictions)}")

# Calculo del F1 score
from sklearn.metrics import f1_score
print(f"F1 Score of the classifier is: {f1_score(y_test, predictions)}")

#Template CURVA - ROC

from sklearn.metrics import roc_curve, auc

class_probabilities = model.predict_proba(X_test)
preds = class_probabilities[:, 1]

fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# AUC
print(f"AUC for our classifier is: {roc_auc}")

# Gráfica de la Curva ROC
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Accuracy of the classifier is: 0.660536398467433
# Precision Score of the classifier is: 0.6271409749670619
# Recall Score of the classifier is: 0.7484276729559748
# F1 Score of the classifier is: 0.6824372759856631
# AUC for our classifier is: 0.7308147897453252

# %% [markdown]
# Observaciones:
# - Es un modelo que le cuesta detectar las clases (en comparación con los Decision Trees).
