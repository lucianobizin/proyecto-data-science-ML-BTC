# %% [markdown]
# # Fecha de entrega: 27/08/2022 (corresponde a clase 20)

# %% [markdown]
# # Algoritmo de clasificación: Support Vector Machine

# %% [markdown]
# # Diccionario

# %% [markdown]
# **BTC_ind_trend_ET_fv** (data set "BTC_ind_trend_ET" reducido según las conclusiones referidas en el punto 7 del documento "Primera entrega")
#
# * Date: fecha en YYYY-MM-DD (object)
# * Price: precio de cierre de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * Open: precio de apertura de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * High: precio más alto de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * Low: precio más bajo de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * Vol.: volumen de BTC (Número de intercambios) en el día de la fecha (float) (Variable numérica continua)
# * Percentage_diff: diferencia porcentual del precio de BTC en la fecha [x+1] con respecto a la fecha [x] (float) (Variable numérica continua)
# * Target: 1 indica que en el día de la fecha el precio de BTC subió, y 0 que el precio bajó (float) (Se la tratará como variable categórica)
# * EMA_7d: media móvil exponencial de 7 días (USD) (float) (Variable numérica continua)
# * HT_TRENDLINE: indicador de Hilbert Transform - Instantaneous Trendline (USD) (float) (Variable numérica continua)
# * BBANDS_upper_band: banda superior del indicador Bandas de Bollinger (USD) (float) (Variable numérica continua)
# * BBANDS_middle_band: banda media del indicador Bandas de Bollinger (USD) (float) (Variable numérica continua)
# * BBANDS_lower_band: banda inferior del indicador Bandas de Bollinger (USD) (float) (Variable numérica continua)
# * PSAR: indicador Parabolic SAR (USD) (float) (Variable numérica continua)Price_silver: indica el precio de cierre de la plata en el día de la fecha (float) (USD) (variable numérica continua)
# * EMA_7d_ET: valores categóricos de la aplicación de la estrategia de trading EMA de 7 días (comprar, vender, mantener posición) (object) (Variable categórica)
# * HT_TRENDLINE_ET: valores categóricos de la aplicación de la estrategia de trading HT Trendline (comprar, vender, mantener posición) (object) (Variable categórica)
# * PSAR_ET: valores categóricos de la aplicación de la estrategia de trading PSAR (comprar, vender, mantener posición) (object) (Variable categórica)
# * Trend: tendencia de la variable "Price" a lo largo de la serie de tiempo (USD) (Variable categórica continua)
# * Residuals: residualidad de la variable "Price" a lo largo de la serie de tiempo (unidad) (Variable categórica continua)

# %% [markdown]
# # Librerías

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas_profiling
import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib.cm import ScalarMappable

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('darkgrid')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Data acquisition

# %%
def gdriveColabPath(sharing_url):
  file_id=sharing_url.split('/')[-2]
  dwn_url='https://drive.google.com/uc?id=' + file_id
  return dwn_url

# %% [markdown]
# ## Adquiriendo BTC_ind_trend_ET_fv

# %%
# Se carga la base de datos de BTC_ind_trend_ET_fv desde la carpeta compartida en el Google Drive
sharing_url = "https://drive.google.com/file/d/1P7EPcqZ-CGRcTPqhk1BE9KZNTdysCr4A/view?usp=sharing"

# %%
dwn_url=gdriveColabPath(sharing_url)
BTC_ind_trend_fv_df = pd.read_csv(dwn_url, sep=";", decimal=".")
BTC_ind_trend_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0
#
#    EMA_7d  HT_TRENDLINE  BBANDS_upper_band  BBANDS_middle_band  \
# 0     NaN           NaN                NaN                 NaN
# 1     NaN           NaN                NaN                 NaN
# 2     NaN           NaN                NaN                 NaN
# 3     NaN           NaN                NaN                 NaN
# 4     NaN           NaN                0.1                 0.1
#
#    BBANDS_lower_band  PSAR          EMA_7d_ET            HTTL_ET  \
# 0                NaN   NaN  Mantener_posicion  Mantener_posicion
# 1                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2                NaN   0.1  Mantener_posicion  Mantener_posicion
# 3                NaN   0.1  Mantener_posicion  Mantener_posicion
# 4                0.1   0.1  Mantener_posicion  Mantener_posicion
#
#              PSAR_ET  Trend  Residuals
# 0  Mantener_posicion    NaN        NaN
# 1  Mantener_posicion    NaN        NaN
# 2  Mantener_posicion    NaN        NaN
# 3  Mantener_posicion    0.1 -19.575231
# 4  Mantener_posicion    0.1  15.128694

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Análisis pre-modelado

# %%
# Registros y columnas
BTC_ind_trend_fv_df.shape
# Out:
# (4386, 19)

# %%
# Nombre de columnas
BTC_ind_trend_fv_df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff',
#        'Target', 'EMA_7d', 'HT_TRENDLINE', 'BBANDS_upper_band',
#        'BBANDS_middle_band', 'BBANDS_lower_band', 'PSAR', 'EMA_7d_ET',
#        'HTTL_ET', 'PSAR_ET', 'Trend', 'Residuals'],
#       dtype='object')

# %%
# Tipos de datos de las variables
BTC_ind_trend_fv_df.dtypes
# Out:
# Date                   object
# Price                 float64
# Open                  float64
# High                  float64
# Low                   float64
# Vol.                  float64
# Percentage_diff       float64
# Target                float64
# EMA_7d                float64
# HT_TRENDLINE          float64
# BBANDS_upper_band     float64
# BBANDS_middle_band    float64
# BBANDS_lower_band     float64
# PSAR                  float64
# EMA_7d_ET              object
# HTTL_ET                object
# PSAR_ET                object
# Trend                 float64
# Residuals             float64
# dtype: object

# %%
# Columnas y cantidad de registros
BTC_ind_trend_fv_df.count()
# Out:
# Date                  4386
# Price                 4386
# Open                  4386
# High                  4386
# Low                   4386
# Vol.                  4386
# Percentage_diff       4386
# Target                4386
# EMA_7d                4380
# HT_TRENDLINE          4323
# BBANDS_upper_band     4382
# BBANDS_middle_band    4382
# BBANDS_lower_band     4382
# PSAR                  4385
# EMA_7d_ET             4386
# HTTL_ET               4386
# PSAR_ET               4386
# Trend                 4380
# Residuals             4380
# dtype: int64

# %%
# Valores NaN
BTC_ind_trend_fv_df.isnull().sum()
# Out:
# Date                   0
# Price                  0
# Open                   0
# High                   0
# Low                    0
# Vol.                   0
# Percentage_diff        0
# Target                 0
# EMA_7d                 6
# HT_TRENDLINE          63
# BBANDS_upper_band      4
# BBANDS_middle_band     4
# BBANDS_lower_band      4
# PSAR                   1
# EMA_7d_ET              0
# HTTL_ET                0
# PSAR_ET                0
# Trend                  6
# Residuals              6
# dtype: int64

# %%
BTC_ind_trend_fv_df.head(10)
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0
# 5  2010-07-23    0.1   0.1   0.1  0.1  2400.0              0.0     0.0
# 6  2010-07-24    0.1   0.1   0.1  0.1   500.0              0.0     0.0
# 7  2010-07-25    0.1   0.1   0.1  0.1  1550.0              0.0     0.0
# 8  2010-07-26    0.1   0.1   0.1  0.1   880.0              0.0     0.0
# 9  2010-07-27    0.1   0.1   0.1  0.1  3370.0              0.0     0.0
#
#    EMA_7d  HT_TRENDLINE  BBANDS_upper_band  BBANDS_middle_band  \
# 0     NaN           NaN                NaN                 NaN
# 1     NaN           NaN                NaN                 NaN
# 2     NaN           NaN                NaN                 NaN
# 3     NaN           NaN                NaN                 NaN
# 4     NaN           NaN                0.1                 0.1
# 5     NaN           NaN                0.1                 0.1
# 6     0.1           NaN                0.1                 0.1
# 7     0.1           NaN                0.1                 0.1
# 8     0.1           NaN                0.1                 0.1
# 9     0.1           NaN                0.1                 0.1
#
#    BBANDS_lower_band  PSAR          EMA_7d_ET            HTTL_ET  \
# 0                NaN   NaN  Mantener_posicion  Mantener_posicion
# 1                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2                NaN   0.1  Mantener_posicion  Mantener_posicion
# 3                NaN   0.1  Mantener_posicion  Mantener_posicion
# 4                0.1   0.1  Mantener_posicion  Mantener_posicion
# 5                0.1   0.1  Mantener_posicion  Mantener_posicion
# 6                0.1   0.1  Mantener_posicion  Mantener_posicion
# 7                0.1   0.1  Mantener_posicion  Mantener_posicion
# 8                0.1   0.1  Mantener_posicion  Mantener_posicion
# 9                0.1   0.1  Mantener_posicion  Mantener_posicion
#
#              PSAR_ET  Trend  Residuals
# 0  Mantener_posicion    NaN        NaN
# 1  Mantener_posicion    NaN        NaN
# 2  Mantener_posicion    NaN        NaN
# 3  Mantener_posicion    0.1 -19.575231
# 4  Mantener_posicion    0.1  15.128694
# 5  Mantener_posicion    0.1  10.352268
# 6  Mantener_posicion    0.1   0.183737
# 7  Mantener_posicion    0.1   3.979105
# 8  Mantener_posicion    0.1  -8.917886
# 9  Mantener_posicion    0.1  -1.150686

# %% [markdown]
# Observaciones:
#
# Se observaron varios registros NaN en "BTC_ind_trend_ET_fv.csv".
#
# Esto implica la necesidad de tomar una decisión con respecto a este tipo de valores (instancia previa al modelado).
#
# Se descarta rellenar los NaN con promedios de valores previos y/o posteriores por varias razones:
#
# 1. En las variables [Trend] y [Residuals], 3 de los 6 valores NaN se encuentran al principio de la serie, y los restantes 3 al final de la misma. Esto significa que no se puede hacer un promedio con valores anteriores y posteriores a los valores NaN sino solo con anteriores o posteriores según el caso. Proceder con un promedio con los datos anteriores o posteriores en una serie de tiempo supone un problema extra (¿cuántos valores hacia atrás o hacia adelante se deben tomar?, ¿cuál es el grado de autocorrelación con los valores anteriores o posteriores?, entre otros).
#
#
# 2. En la variable [Residuals] hay valores positivos y negativos en los registros anteriores y posteriores inmediatos según el caso. Esto también añade un problema extra (¿qué signo se debería utilizar si se rellenan esos casilleros?).
#
#
# 3. Al no tratarse de un problema de regresión lineal del valor que tomaría el precio de BTC en el registro siguiente sino un problema de clasificación, la eliminación de los valores NaN no afectaría en demasía la predicción del modelo a pesar de la autocorrelación referida en el punto 2. Si se considera eliminar los 63 registros NaN (variable -> HT_TRENDLINE) se estarí solamente eliminando un (63*100/4386 =) 1.43 % de los datos.
#
# Se eliminan los valores NaN dado que el modelo no acepta este tipos de valores (las razones son las aducidas arriba).

# %% [markdown]
# ## Ultimas manipulaciones pre-modelado

# %% [markdown]
# Se reindexa el data set que se modelará a fin de que la variable [Date] funcione como nuevo índice de la base de datos.

# %%
# Se crea una copia de BTC_ind_trend_fv_df con nombre BTC_ind_trend y se la reindexa con la variable [Date] como nuevo índice
BTC_ind_trend = BTC_ind_trend_fv_df.set_index("Date")

# %%
BTC_ind_trend.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target        EMA_7d  HT_TRENDLINE  BBANDS_upper_band  \
# Date
# 2022-07-16     1.0  20679.126620  20423.078104       21714.292433
# 2022-07-17     0.0  20705.744965  20403.832160       21359.693563
# 2022-07-18     1.0  21160.758724  20435.796762       22585.394742
# 2022-07-19     1.0  21723.119043  20547.109474       23836.570363
# 2022-07-20     0.0  22079.614282  20712.814316       24304.381782
#
#             BBANDS_middle_band  BBANDS_lower_band          PSAR  \
# Date
# 2022-07-16            20440.38       19166.467567  22017.409626
# 2022-07-17            20731.32       20102.946437  21894.401241
# 2022-07-18            21186.48       19787.565258  18942.200000
# 2022-07-19            21751.32       19666.069637  19017.654000
# 2022-07-20            22216.12       20127.858218  19207.239840
#
#                     EMA_7d_ET            HTTL_ET            PSAR_ET  \
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-17  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-18  Mantener_posicion  Mantener_posicion            Comprar
# 2022-07-19  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-20  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                    Trend   Residuals
# Date
# 2022-07-16  21370.371429 -160.287691
# 2022-07-17  21784.528571 -994.949467
# 2022-07-18           NaN         NaN
# 2022-07-19           NaN         NaN
# 2022-07-20           NaN         NaN

# %% [markdown]
# Dado que en la práctica real solo se tiene hasta los valores del registro anterior al que se quiere predecir se intenta hacer un shift (-1) a la variable [Target]. Se entiende que así (en caso de que el modelo prediga con previsibilidad suficiente) se podría estar seguro de que después vendría el valor de [Target] original sin shift (-1).

# %%
# Se genera un back up
BTC_ind_trend_2 = BTC_ind_trend.copy()

# %%
# Se realiza el shift 
BTC_ind_trend_2 ["Target"] = BTC_ind_trend ["Target"].shift(-1)

# %%
BTC_ind_trend_2.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target        EMA_7d  HT_TRENDLINE  BBANDS_upper_band  \
# Date
# 2022-07-16     0.0  20679.126620  20423.078104       21714.292433
# 2022-07-17     1.0  20705.744965  20403.832160       21359.693563
# 2022-07-18     1.0  21160.758724  20435.796762       22585.394742
# 2022-07-19     0.0  21723.119043  20547.109474       23836.570363
# 2022-07-20     NaN  22079.614282  20712.814316       24304.381782
#
#             BBANDS_middle_band  BBANDS_lower_band          PSAR  \
# Date
# 2022-07-16            20440.38       19166.467567  22017.409626
# 2022-07-17            20731.32       20102.946437  21894.401241
# 2022-07-18            21186.48       19787.565258  18942.200000
# 2022-07-19            21751.32       19666.069637  19017.654000
# 2022-07-20            22216.12       20127.858218  19207.239840
#
#                     EMA_7d_ET            HTTL_ET            PSAR_ET  \
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-17  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-18  Mantener_posicion  Mantener_posicion            Comprar
# 2022-07-19  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-20  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                    Trend   Residuals
# Date
# 2022-07-16  21370.371429 -160.287691
# 2022-07-17  21784.528571 -994.949467
# 2022-07-18           NaN         NaN
# 2022-07-19           NaN         NaN
# 2022-07-20           NaN         NaN

# %% [markdown]
# Se convierten las variables categóricas ([EMA_7d_ET], [HTTL_ET], [PSAR_ET]) en variables dummies y se agregan a BTC_ind_trend_2

# %%
Variables = ["EMA_7d_ET", "HTTL_ET", "PSAR_ET"]

for var in Variables:
    dummies = pd.get_dummies(BTC_ind_trend_2 [var])
    dummies = dummies.rename(columns={"Comprar":"Comprar_"+var+"", "Mantener_posicion":"Mantener_posicion_"+var+"", "Vender":"Vender_"+var+""})
    BTC_ind_trend_2 = pd.concat([BTC_ind_trend_2, dummies], axis = 1)

# %%
BTC_ind_trend_2.head()
# Out:
#             Price  Open  High  Low    Vol.  Percentage_diff  Target  EMA_7d  \
# Date
# 2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0     NaN
# 2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0     NaN
# 2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0     NaN
# 2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0     NaN
# 2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0     NaN
#
#             HT_TRENDLINE  BBANDS_upper_band  BBANDS_middle_band  \
# Date
# 2010-07-18           NaN                NaN                 NaN
# 2010-07-19           NaN                NaN                 NaN
# 2010-07-20           NaN                NaN                 NaN
# 2010-07-21           NaN                NaN                 NaN
# 2010-07-22           NaN                0.1                 0.1
#
#             BBANDS_lower_band  PSAR          EMA_7d_ET            HTTL_ET  \
# Date
# 2010-07-18                NaN   NaN  Mantener_posicion  Mantener_posicion
# 2010-07-19                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2010-07-20                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2010-07-21                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2010-07-22                0.1   0.1  Mantener_posicion  Mantener_posicion
#
#                       PSAR_ET  Trend  Residuals  Comprar_EMA_7d_ET  \
# Date
# 2010-07-18  Mantener_posicion    NaN        NaN                  0
# 2010-07-19  Mantener_posicion    NaN        NaN                  0
# 2010-07-20  Mantener_posicion    NaN        NaN                  0
# 2010-07-21  Mantener_posicion    0.1 -19.575231                  0
# 2010-07-22  Mantener_posicion    0.1  15.128694                  0
#
#             Mantener_posicion_EMA_7d_ET  Vender_EMA_7d_ET  Comprar_HTTL_ET  \
# Date
# 2010-07-18                            1                 0                0
# 2010-07-19                            1                 0                0
# 2010-07-20                            1                 0                0
# 2010-07-21                            1                 0                0
# 2010-07-22                            1                 0                0
#
#             Mantener_posicion_HTTL_ET  Vender_HTTL_ET  Comprar_PSAR_ET  \
# Date
# 2010-07-18                          1               0                0
# 2010-07-19                          1               0                0
# 2010-07-20                          1               0                0
# 2010-07-21                          1               0                0
# 2010-07-22                          1               0                0
#
#             Mantener_posicion_PSAR_ET  Vender_PSAR_ET
# Date
# 2010-07-18                          1               0
# 2010-07-19                          1               0
# 2010-07-20                          1               0
# 2010-07-21                          1               0
# 2010-07-22                          1               0

# %% [markdown]
# Se eliminan las variables categóricas del BTC_ind_trend_2

# %%
BTC_ind_trend_2 = BTC_ind_trend_2.drop(["EMA_7d_ET", "HTTL_ET", "PSAR_ET"], axis=1)

# %%
BTC_ind_trend_2.columns
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff', 'Target',
#        'EMA_7d', 'HT_TRENDLINE', 'BBANDS_upper_band', 'BBANDS_middle_band',
#        'BBANDS_lower_band', 'PSAR', 'Trend', 'Residuals', 'Comprar_EMA_7d_ET',
#        'Mantener_posicion_EMA_7d_ET', 'Vender_EMA_7d_ET', 'Comprar_HTTL_ET',
#        'Mantener_posicion_HTTL_ET', 'Vender_HTTL_ET', 'Comprar_PSAR_ET',
#        'Mantener_posicion_PSAR_ET', 'Vender_PSAR_ET'],
#       dtype='object')

# %% [markdown]
# Se elimina el registro NaN de la variable [Target] dado que los modelos no pueden procesar este tipo de datos

# %%
BTC_ind_trend_2 = BTC_ind_trend_2 [0:4385]

# %%
BTC_ind_trend_2.isnull().sum()
# Out:
# Price                           0
# Open                            0
# High                            0
# Low                             0
# Vol.                            0
# Percentage_diff                 0
# Target                          0
# EMA_7d                          6
# HT_TRENDLINE                   63
# BBANDS_upper_band               4
# BBANDS_middle_band              4
# BBANDS_lower_band               4
# PSAR                            1
# Trend                           5
# Residuals                       5
# Comprar_EMA_7d_ET               0
# Mantener_posicion_EMA_7d_ET     0
# Vender_EMA_7d_ET                0
# Comprar_HTTL_ET                 0
# Mantener_posicion_HTTL_ET       0
# Vender_HTTL_ET                  0
# Comprar_PSAR_ET                 0
# Mantener_posicion_PSAR_ET       0
# Vender_PSAR_ET                  0
# dtype: int64

# %% [markdown]
# Se eliminan los valores NaN

# %%
BTC_ind_trend_2 = BTC_ind_trend_2.dropna()

# %%
BTC_ind_trend_2.isnull().sum()
# Out:
# Price                          0
# Open                           0
# High                           0
# Low                            0
# Vol.                           0
# Percentage_diff                0
# Target                         0
# EMA_7d                         0
# HT_TRENDLINE                   0
# BBANDS_upper_band              0
# BBANDS_middle_band             0
# BBANDS_lower_band              0
# PSAR                           0
# Trend                          0
# Residuals                      0
# Comprar_EMA_7d_ET              0
# Mantener_posicion_EMA_7d_ET    0
# Vender_EMA_7d_ET               0
# Comprar_HTTL_ET                0
# Mantener_posicion_HTTL_ET      0
# Vender_HTTL_ET                 0
# Comprar_PSAR_ET                0
# Mantener_posicion_PSAR_ET      0
# Vender_PSAR_ET                 0
# dtype: int64

# %% [markdown]
# # Modelado (SVM)

# %% [markdown]
# **...Recordando que...**
#
# *Objetivo general del proyecto*
#
# I.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) el dinamismo del precio de Bitcoin en el corto plazo, es decir, si el precio de este criptoactivo subirá o bajará en la temporalidad estudiada (1 día).
#
# **...Recordando que...**
#
# *Objetivo específico del proyecto*
#
# III.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) y a corto plazo, el movimiento alcista o bajista del precio de BTC.

# %% [markdown]
# **Explicación**:
#
# En lo que sigue se procederá a realizar varios modelos supervisados de clasificación de tipo "SVM" luego de ejecutar un modelo PCA.
#
# Estos serán configurados con diversos hiperparámetros a fin de encontrar el resultado más óptimo para este data set.
#
# La variable target del modelo es la columna [Target] de BTC_ind_trend_2.

# %% [markdown]
# ## Se genera un modelo PCA

# %%
# Se genera la variable X (variables) e y (target)
X = BTC_ind_trend_2.drop ('Target', axis=1)
y = BTC_ind_trend_2 ['Target']

# %%
# Se separa el data set en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Se normalizan los datos para que PCA otorgue mejores resultados
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Se aplica PCA
pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Se analiza la varianza de cada componente
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([4.78710811e-01, 1.09254794e-01, 8.32154785e-02, 7.89360237e-02,
#        6.17178670e-02, 4.39182143e-02, 4.14208044e-02, 3.96540545e-02,
#        3.30466905e-02, 2.86540415e-02, 8.56745123e-04, 3.71299805e-04,
#        1.33049440e-04, 4.98187153e-05, 3.24988308e-05, 2.06118121e-05,
#        5.26910438e-06, 1.91590273e-06, 1.16526038e-08, 7.98835465e-33,
#        2.26171126e-33, 1.64085537e-33, 5.20992661e-34])

# %% [markdown]
# Observaciones:
# - Las primeras diez variables expresan el 99% de la varianza de los datos.

# %%
# Se genera la variable X (variables) e y (target)
X = BTC_ind_trend_2.drop ('Target', axis=1)
y = BTC_ind_trend_2 ['Target']

# %%
# Se separa el data set en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Se normalizan los datos para que PCA otorgue mejores resultados
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Se genera un nuevo PCA con 10 componentes (las variables que recogen el 99 % de la varianza de los datos)
pca = PCA(n_components=10)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Se definen los parámetros de búsqueda
param_grid= {'kernel': ['linear', 'rbf'],
             'C': [0.1, 1, 10, 100, 1000],
             'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
             'random_state':np.arange(1,10000,50),
             'class_weight': ['balanced'] }

from sklearn.model_selection import RandomizedSearchCV
grid_SVM = RandomizedSearchCV(SVC(), param_grid, refit=True, verbose=3, n_iter=100, cv=5)

# %%
grid_SVM.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=8401;, score=0.647 total time=   0.3s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=8401;, score=0.559 total time=   0.3s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=8401;, score=0.559 total time=   0.3s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=8401;, score=0.586 total time=   0.3s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=linear, random_state=8401;, score=0.590 total time=   0.2s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5751;, score=0.614 total time=   0.7s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5751;, score=0.563 total time=   0.8s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5751;, score=0.554 total time=   0.7s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5751;, score=0.593 total time=   0.8s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.001, kernel=linear, random_state=5751;, score=0.583 total time=   0.8s
# [CV 1/5] END C=100, class_weight=balanced, gamma=1, kernel=linear, random_state=1301;, score=0.601 total time=   3.4s
# [CV 2/5] END C=100, class_weight=balanced, gamma=1, kernel=linear, random_state=1301;, score=0.563 total time=   3.7s
# [CV 3/5] END C=100, class_weight=balanced, gamma=1, kernel=linear, random_state=1301;, score=0.556 total time=   3.9s
# [CV 4/5] END C=100, class_weight=balanced, gamma=1, kernel=linear, random_state=1301;, score=0.593 total time=   3.8s
# [CV 5/5] END C=100, class_weight=balanced, gamma=1, kernel=linear, random_state=1301;, score=0.583 total time=   3.5s
# [CV 1/5] END C=100, class_weight=balanced, gamma=1, kernel=rbf, random_state=7901;, score=0.647 total time=   0.7s
# [CV 2/5] END C=100, class_weight=balanced, gamma=1, kernel=rbf, random_state=7901;, score=0.634 total time=   0.8s
# [CV 3/5] END C=100, class_weight=balanced, gamma=1, kernel=rbf, random_state=7901;, score=0.611 total time=   0.9s
# [CV 4/5] END C=100, class_weight=balanced, gamma=1, kernel=rbf, random_state=7901;, score=0.614 total time=   0.8s
# [CV 5/5] END C=100, class_weight=balanced, gamma=1, kernel=rbf, random_state=7901;, score=0.583 total time=   0.7s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=7951;, score=0.666 total time=   0.6s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=7951;, score=0.624 total time=   0.7s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=7951;, score=0.627 total time=   0.7s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=7951;, score=0.631 total time=   0.7s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=7951;, score=0.606 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=8901;, score=0.639 total time=   0.9s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=8901;, score=0.622 total time=   1.0s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=8901;, score=0.641 total time=   1.0s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=8901;, score=0.615 total time=   1.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=8901;, score=0.589 total time=   1.1s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=linear, random_state=8001;, score=0.603 total time=  24.0s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=linear, random_state=8001;, score=0.560 total time=  23.7s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=linear, random_state=8001;, score=0.553 total time=  26.0s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=linear, random_state=8001;, score=0.593 total time=  23.6s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=linear, random_state=8001;, score=0.585 total time=  23.0s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.01, kernel=linear, random_state=9851;, score=0.601 total time=   3.4s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.01, kernel=linear, random_state

# [CV 1/5] END C=1, class_weight=balanced, gamma=1, kernel=linear, random_state=551;, score=0.613 total time=   0.3s
# [CV 2/5] END C=1, class_weight=balanced, gamma=1, kernel=linear, random_state=551;, score=0.564 total time=   0.3s
# [CV 3/5] END C=1, class_weight=balanced, gamma=1, kernel=linear, random_state=551;, score=0.554 total time=   0.3s
# [CV 4/5] END C=1, class_weight=balanced, gamma=1, kernel=linear, random_state=551;, score=0.595 total time=   0.3s
# [CV 5/5] END C=1, class_weight=balanced, gamma=1, kernel=linear, random_state=551;, score=0.585 total time=   0.3s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3551;, score=0.512 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3551;, score=0.488 total time=   0.6s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3551;, score=0.488 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3551;, score=0.488 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3551;, score=0.511 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=9201;, score=0.603 total time=  23.6s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=9201;, score=0.560 total time=  23.5s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=9201;, score=0.553 total time=  25.4s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=9201;, score=0.593 total time=  23.6s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=linear, random_state=9201;, score=0.585 total time=  23.3s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3851;, score=0.605 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3851;, score=0.576 total time=   0.6s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3851;, score=0.608 total time=   0.6s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3851;, score=0.582 total time=   0.6s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3851;, score=0.577 total time=   0.6s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, random_state=2951;, score=0.647 total time=   0.2s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, random_state=2951;, score=0.559 total time=   0.3s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, random_state=2951;, score=0.559 total time=   0.3s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, random_state=2951;, score=0.586 total time=   0.2s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=linear, random_state=2951;, score=0.590 total time=   0.3s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=9001;, score=0.616 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=9001;, score=0.577 total time=   0.6s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=9001;, score=0.554 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=9001;, score=0.570 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=9001;, score=0.583 total time=   0.6s
# [CV 1/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=2601;, score=0.620 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=2601;, score=0.611 total time=   0.5s
# [CV 3/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=2601;, score=0.596 total time=   0.5s
# [CV 4/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=2601;, score=0.608 total time=   0.5s
# [CV 5/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=2601;, score=0.609 total time=   0.5s
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=100,
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'class_weight': ['balanced'],
#                                         'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                                         'kernel': ['linear', 'rbf'],
#                                         'random_state': array([   1,   51,  101,  151,  201,  251,  301,  351,  401,  451,  501,
#         551,  601,  651,  701,  751,  801,  851,  901,  951, 1001, 1051,
#        1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601,
#        16...
#        6601, 6651, 6701, 6751, 6801, 6851, 6901, 6951, 7001, 7051, 7101,
#        7151, 7201, 7251, 7301, 7351, 7401, 7451, 7501, 7551, 7601, 7651,
#        7701, 7751, 7801, 7851, 7901, 7951, 8001, 8051, 8101, 8151, 8201,
#        8251, 8301, 8351, 8401, 8451, 8501, 8551, 8601, 8651, 8701, 8751,
#        8801, 8851, 8901, 8951, 9001, 9051, 9101, 9151, 9201, 9251, 9301,
#        9351, 9401, 9451, 9501, 9551, 9601, 9651, 9701, 9751, 9801, 9851,
#        9901, 9951])},
#                    verbose=3)

# %%
# print best parameter after tuning
print(grid_SVM.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid_SVM.best_estimator_)
# Out:
# {'random_state': 7951, 'kernel': 'rbf', 'gamma': 0.1, 'class_weight': 'balanced', 'C': 100}
# SVC(C=100, class_weight='balanced', gamma=0.1, random_state=7951)

# %%
# Se crea el modelo SVM 
modelo = SVC(C = 100, kernel = 'rbf', gamma=0.1, class_weight = "balanced", random_state=7951)

# %%
# Se entrena al modelo
modelo.fit(X_train, y_train)
# Out:
# SVC(C=100, class_weight='balanced', gamma=0.1, random_state=7951)

# %%
# Se busca conocer las predicciones del modelo
y_train_pred = modelo.predict(X_train)
y_test_pred = modelo.predict(X_test)

# %%
# Se calcula el accuracy en los datos de train
train_accuracy = accuracy_score(y_train, y_train_pred)
print('% de aciertos sobre el set de evaluación para train:', train_accuracy)

# Se calcula el accuracy en los datos de test
test_accuracy = accuracy_score(y_test, y_test_pred)
print('% de aciertos sobre el set de evaluación para test:', test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación para train: 0.6953125
# % de aciertos sobre el set de evaluación para test: 0.6296296296296297

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# Predicciones
predictions = modelo.predict(X_test)

#Matriz de Confusión
print(confusion_matrix(y_test, predictions))

#Ploteamos la Matriz
plot_confusion_matrix(modelo, X_test, y_test)
plt.show()
# Out:
# [[319 112]
#  [208 225]]

# %% [markdown]
# Observaciones:
# - El modelo es mejor prediciendo los casos de bajda de precio pero no de subida.
# - El modelo genera muchos casos de falsos negativos.

# %%
# Accuracy
print(f"Accuracy of the classifier is: {accuracy_score(y_test, predictions)}")

# Precision
from sklearn.metrics import precision_score
print(f"Precision Score of the classifier is: {precision_score(y_test, predictions)}")

# Recall
from sklearn.metrics import recall_score
print(f"Recall Score of the classifier is: {recall_score(y_test, predictions)}")

# Calculo del F1 score
from sklearn.metrics import f1_score
print(f"F1 Score of the classifier is: {f1_score(y_test, predictions)}")
# Out:
# Accuracy of the classifier is: 0.6296296296296297
# Precision Score of the classifier is: 0.6676557863501483
# Recall Score of the classifier is: 0.5196304849884527
# F1 Score of the classifier is: 0.5844155844155844

# %% [markdown]
# Observaciones:
# - El mejor modelo predice en un 63% de los casos si el precio de BTC sube o baja.
