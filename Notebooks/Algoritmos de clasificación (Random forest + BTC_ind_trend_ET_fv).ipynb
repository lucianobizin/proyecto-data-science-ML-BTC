# %% [markdown]
# # Fecha de entrega: 27/08/2022 (corresponde a clase 20)

# %% [markdown]
# # Algoritmo de clasificación: Random forest

# %% [markdown]
# # Diccionario

# %% [markdown]
# **BTC_ind_trend_ET_fv** (data set "BTC_ind_trend_ET" reducido según las conclusiones referidas en el punto 7 del documento "Primera entrega")
#
# * Date: fecha en YYYY-MM-DD (object)
# * Price: precio de cierre de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * Open: precio de apertura de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * High: precio más alto de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * Low: precio más bajo de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# * Vol.: volumen de BTC (Número de intercambios) en el día de la fecha (float) (Variable numérica continua)
# * Percentage_diff: diferencia porcentual del precio de BTC en la fecha [x+1] con respecto a la fecha [x] (float) (Variable numérica continua)
# * Target: 1 indica que en el día de la fecha el precio de BTC subió, y 0 que el precio bajó (float) (Se la tratará como variable categórica)
# * EMA_7d: media móvil exponencial de 7 días (USD) (float) (Variable numérica continua)
# * HT_TRENDLINE: indicador de Hilbert Transform - Instantaneous Trendline (USD) (float) (Variable numérica continua)
# * BBANDS_upper_band: banda superior del indicador Bandas de Bollinger (USD) (float) (Variable numérica continua)
# * BBANDS_middle_band: banda media del indicador Bandas de Bollinger (USD) (float) (Variable numérica continua)
# * BBANDS_lower_band: banda inferior del indicador Bandas de Bollinger (USD) (float) (Variable numérica continua)
# * PSAR: indicador Parabolic SAR (USD) (float) (Variable numérica continua)Price_silver: indica el precio de cierre de la plata en el día de la fecha (float) (USD) (variable numérica continua)
# * EMA_7d_ET: valores categóricos de la aplicación de la estrategia de trading EMA de 7 días (comprar, vender, mantener posición) (object) (Variable categórica)
# * HT_TRENDLINE_ET: valores categóricos de la aplicación de la estrategia de trading HT Trendline (comprar, vender, mantener posición) (object) (Variable categórica)
# * PSAR_ET: valores categóricos de la aplicación de la estrategia de trading PSAR (comprar, vender, mantener posición) (object) (Variable categórica)
# * Trend: tendencia de la variable "Price" a lo largo de la serie de tiempo (USD) (Variable categórica continua)
# * Residuals: residualidad de la variable "Price" a lo largo de la serie de tiempo (unidad) (Variable categórica continua)

# %% [markdown]
# # Librerías

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas_profiling
import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib.cm import ScalarMappable

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor 

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('darkgrid')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# # Data acquisition

# %%
def gdriveColabPath(sharing_url):
  file_id=sharing_url.split('/')[-2]
  dwn_url='https://drive.google.com/uc?id=' + file_id
  return dwn_url

# %%
# Se carga la base de datos de BTC_ind_trend_ET_fv desde la carpeta compartida en el Google Drive
sharing_url = "https://drive.google.com/file/d/1P7EPcqZ-CGRcTPqhk1BE9KZNTdysCr4A/view?usp=sharing"

# %%
dwn_url=gdriveColabPath(sharing_url)
BTC_ind_trend_fv_df = pd.read_csv(dwn_url, sep=";", decimal=".")
BTC_ind_trend_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0
#
#    EMA_7d  HT_TRENDLINE  BBANDS_upper_band  BBANDS_middle_band  \
# 0     NaN           NaN                NaN                 NaN
# 1     NaN           NaN                NaN                 NaN
# 2     NaN           NaN                NaN                 NaN
# 3     NaN           NaN                NaN                 NaN
# 4     NaN           NaN                0.1                 0.1
#
#    BBANDS_lower_band  PSAR          EMA_7d_ET            HTTL_ET  \
# 0                NaN   NaN  Mantener_posicion  Mantener_posicion
# 1                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2                NaN   0.1  Mantener_posicion  Mantener_posicion
# 3                NaN   0.1  Mantener_posicion  Mantener_posicion
# 4                0.1   0.1  Mantener_posicion  Mantener_posicion
#
#              PSAR_ET  Trend  Residuals
# 0  Mantener_posicion    NaN        NaN
# 1  Mantener_posicion    NaN        NaN
# 2  Mantener_posicion    NaN        NaN
# 3  Mantener_posicion    0.1 -19.575231
# 4  Mantener_posicion    0.1  15.128694

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Análisis pre-modelado

# %%
# Registros y columnas
BTC_ind_trend_fv_df.shape
# Out:
# (4386, 19)

# %%
# Nombre de columnas
BTC_ind_trend_fv_df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff',
#        'Target', 'EMA_7d', 'HT_TRENDLINE', 'BBANDS_upper_band',
#        'BBANDS_middle_band', 'BBANDS_lower_band', 'PSAR', 'EMA_7d_ET',
#        'HTTL_ET', 'PSAR_ET', 'Trend', 'Residuals'],
#       dtype='object')

# %%
# Tipos de datos de las variables
BTC_ind_trend_fv_df.dtypes
# Out:
# Date                   object
# Price                 float64
# Open                  float64
# High                  float64
# Low                   float64
# Vol.                  float64
# Percentage_diff       float64
# Target                float64
# EMA_7d                float64
# HT_TRENDLINE          float64
# BBANDS_upper_band     float64
# BBANDS_middle_band    float64
# BBANDS_lower_band     float64
# PSAR                  float64
# EMA_7d_ET              object
# HTTL_ET                object
# PSAR_ET                object
# Trend                 float64
# Residuals             float64
# dtype: object

# %%
# Columnas y cantidad de registros
BTC_ind_trend_fv_df.count()
# Out:
# Date                  4386
# Price                 4386
# Open                  4386
# High                  4386
# Low                   4386
# Vol.                  4386
# Percentage_diff       4386
# Target                4386
# EMA_7d                4380
# HT_TRENDLINE          4323
# BBANDS_upper_band     4382
# BBANDS_middle_band    4382
# BBANDS_lower_band     4382
# PSAR                  4385
# EMA_7d_ET             4386
# HTTL_ET               4386
# PSAR_ET               4386
# Trend                 4380
# Residuals             4380
# dtype: int64

# %%
# Valores NaN
BTC_ind_trend_fv_df.isnull().sum()
# Out:
# Date                   0
# Price                  0
# Open                   0
# High                   0
# Low                    0
# Vol.                   0
# Percentage_diff        0
# Target                 0
# EMA_7d                 6
# HT_TRENDLINE          63
# BBANDS_upper_band      4
# BBANDS_middle_band     4
# BBANDS_lower_band      4
# PSAR                   1
# EMA_7d_ET              0
# HTTL_ET                0
# PSAR_ET                0
# Trend                  6
# Residuals              6
# dtype: int64

# %%
BTC_ind_trend_fv_df.head(10)
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0
# 5  2010-07-23    0.1   0.1   0.1  0.1  2400.0              0.0     0.0
# 6  2010-07-24    0.1   0.1   0.1  0.1   500.0              0.0     0.0
# 7  2010-07-25    0.1   0.1   0.1  0.1  1550.0              0.0     0.0
# 8  2010-07-26    0.1   0.1   0.1  0.1   880.0              0.0     0.0
# 9  2010-07-27    0.1   0.1   0.1  0.1  3370.0              0.0     0.0
#
#    EMA_7d  HT_TRENDLINE  BBANDS_upper_band  BBANDS_middle_band  \
# 0     NaN           NaN                NaN                 NaN
# 1     NaN           NaN                NaN                 NaN
# 2     NaN           NaN                NaN                 NaN
# 3     NaN           NaN                NaN                 NaN
# 4     NaN           NaN                0.1                 0.1
# 5     NaN           NaN                0.1                 0.1
# 6     0.1           NaN                0.1                 0.1
# 7     0.1           NaN                0.1                 0.1
# 8     0.1           NaN                0.1                 0.1
# 9     0.1           NaN                0.1                 0.1
#
#    BBANDS_lower_band  PSAR          EMA_7d_ET            HTTL_ET  \
# 0                NaN   NaN  Mantener_posicion  Mantener_posicion
# 1                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2                NaN   0.1  Mantener_posicion  Mantener_posicion
# 3                NaN   0.1  Mantener_posicion  Mantener_posicion
# 4                0.1   0.1  Mantener_posicion  Mantener_posicion
# 5                0.1   0.1  Mantener_posicion  Mantener_posicion
# 6                0.1   0.1  Mantener_posicion  Mantener_posicion
# 7                0.1   0.1  Mantener_posicion  Mantener_posicion
# 8                0.1   0.1  Mantener_posicion  Mantener_posicion
# 9                0.1   0.1  Mantener_posicion  Mantener_posicion
#
#              PSAR_ET  Trend  Residuals
# 0  Mantener_posicion    NaN        NaN
# 1  Mantener_posicion    NaN        NaN
# 2  Mantener_posicion    NaN        NaN
# 3  Mantener_posicion    0.1 -19.575231
# 4  Mantener_posicion    0.1  15.128694
# 5  Mantener_posicion    0.1  10.352268
# 6  Mantener_posicion    0.1   0.183737
# 7  Mantener_posicion    0.1   3.979105
# 8  Mantener_posicion    0.1  -8.917886
# 9  Mantener_posicion    0.1  -1.150686

# %% [markdown]
# Observaciones:
#
# Se observaron varios registros NaN en "BTC_ind_trend_ET_fv.csv".
#
# Esto implica la necesidad de tomar una decisión con respecto a este tipo de valores (instancia previa al modelado).
#
# Se descarta rellenar los NaN con promedios de valores previos y/o posteriores por varias razones:
#
# 1. En las variables [Trend] y [Residuals], 3 de los 6 valores NaN se encuentran al principio de la serie, y los restantes 3 al final de la misma. Esto significa que no se puede hacer un promedio con valores anteriores y posteriores a los valores NaN sino solo con anteriores o posteriores según el caso. Proceder con un promedio con los datos anteriores o posteriores en una serie de tiempo supone un problema extra (¿cuántos valores hacia atrás o hacia adelante se deben tomar?, ¿cuál es el grado de autocorrelación con los valores anteriores o posteriores?, entre otros).
#
#
# 2. En la variable [Residuals] hay valores positivos y negativos en los registros anteriores y posteriores inmediatos según el caso. Esto también añade un problema extra (¿qué signo se debería utilizar si se rellenan esos casilleros?).
#
#
# 3. Al no tratarse de un problema de regresión lineal del valor que tomaría el precio de BTC en el registro siguiente sino un problema de clasificación, la eliminación de los valores NaN no afectaría en demasía la predicción del modelo a pesar de la autocorrelación referida en el punto 2. Si se considera eliminar los 63 registros NaN (variable -> HT_TRENDLINE) se estarí solamente eliminando un (63*100/4386 =) 1.43 % de los datos.
#
# Solución: dado que el modelo Random Forest no acepta valores NaN, por las razones aducidas arriba, se eliminan.

# %% [markdown]
# ## Ultimas manipulaciones pre-modelado

# %% [markdown]
# Se reindexa el data set que se modelará a fin de que la variable [Date] funcione como nuevo índice de la base de datos.

# %%
# Se crea una copia de BTC_ind_trend_fv_df con nombre BTC_ind_trend y se la reindexa con la variable [Date] como nuevo índice
BTC_ind_trend = BTC_ind_trend_fv_df.set_index("Date")

# %%
BTC_ind_trend.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target        EMA_7d  HT_TRENDLINE  BBANDS_upper_band  \
# Date
# 2022-07-16     1.0  20679.126620  20423.078104       21714.292433
# 2022-07-17     0.0  20705.744965  20403.832160       21359.693563
# 2022-07-18     1.0  21160.758724  20435.796762       22585.394742
# 2022-07-19     1.0  21723.119043  20547.109474       23836.570363
# 2022-07-20     0.0  22079.614282  20712.814316       24304.381782
#
#             BBANDS_middle_band  BBANDS_lower_band          PSAR  \
# Date
# 2022-07-16            20440.38       19166.467567  22017.409626
# 2022-07-17            20731.32       20102.946437  21894.401241
# 2022-07-18            21186.48       19787.565258  18942.200000
# 2022-07-19            21751.32       19666.069637  19017.654000
# 2022-07-20            22216.12       20127.858218  19207.239840
#
#                     EMA_7d_ET            HTTL_ET            PSAR_ET  \
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-17  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-18  Mantener_posicion  Mantener_posicion            Comprar
# 2022-07-19  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-20  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                    Trend   Residuals
# Date
# 2022-07-16  21370.371429 -160.287691
# 2022-07-17  21784.528571 -994.949467
# 2022-07-18           NaN         NaN
# 2022-07-19           NaN         NaN
# 2022-07-20           NaN         NaN

# %% [markdown]
# Dado que en la práctica real solo se tiene hasta los valores del registro anterior al que se quiere predecir se intenta hacer un shift (-1) a la variable [Target]. Se entiende que así (en caso de que el modelo prediga con previsibilidad suficiente) se podría estar seguro de que después vendría el valor de [Target] original sin shift (-1).

# %%
# Se genera un back up
BTC_ind_trend_2 = BTC_ind_trend.copy()

# %%
# Se realiza el shift 
BTC_ind_trend_2 ["Target"] = BTC_ind_trend ["Target"].shift(-1)

# %%
BTC_ind_trend_2.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target        EMA_7d  HT_TRENDLINE  BBANDS_upper_band  \
# Date
# 2022-07-16     0.0  20679.126620  20423.078104       21714.292433
# 2022-07-17     1.0  20705.744965  20403.832160       21359.693563
# 2022-07-18     1.0  21160.758724  20435.796762       22585.394742
# 2022-07-19     0.0  21723.119043  20547.109474       23836.570363
# 2022-07-20     NaN  22079.614282  20712.814316       24304.381782
#
#             BBANDS_middle_band  BBANDS_lower_band          PSAR  \
# Date
# 2022-07-16            20440.38       19166.467567  22017.409626
# 2022-07-17            20731.32       20102.946437  21894.401241
# 2022-07-18            21186.48       19787.565258  18942.200000
# 2022-07-19            21751.32       19666.069637  19017.654000
# 2022-07-20            22216.12       20127.858218  19207.239840
#
#                     EMA_7d_ET            HTTL_ET            PSAR_ET  \
# Date
# 2022-07-16  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-17  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-18  Mantener_posicion  Mantener_posicion            Comprar
# 2022-07-19  Mantener_posicion  Mantener_posicion  Mantener_posicion
# 2022-07-20  Mantener_posicion  Mantener_posicion  Mantener_posicion
#
#                    Trend   Residuals
# Date
# 2022-07-16  21370.371429 -160.287691
# 2022-07-17  21784.528571 -994.949467
# 2022-07-18           NaN         NaN
# 2022-07-19           NaN         NaN
# 2022-07-20           NaN         NaN

# %% [markdown]
# Se convierten las variables categóricas ([EMA_7d_ET], [HTTL_ET], [PSAR_ET]) en variables dummies y se agregan a BTC_ind_trend_2

# %%
Variables = ["EMA_7d_ET", "HTTL_ET", "PSAR_ET"]

for var in Variables:
    dummies = pd.get_dummies(BTC_ind_trend_2 [var])
    dummies = dummies.rename(columns={"Comprar":"Comprar_"+var+"", "Mantener_posicion":"Mantener_posicion_"+var+"", "Vender":"Vender_"+var+""})
    BTC_ind_trend_2 = pd.concat([BTC_ind_trend_2, dummies], axis = 1)

# %%
BTC_ind_trend_2.head()
# Out:
#             Price  Open  High  Low    Vol.  Percentage_diff  Target  EMA_7d  \
# Date
# 2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0     0.0     NaN
# 2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0     0.0     NaN
# 2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0     0.0     NaN
# 2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0     0.0     NaN
# 2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0     0.0     NaN
#
#             HT_TRENDLINE  BBANDS_upper_band  BBANDS_middle_band  \
# Date
# 2010-07-18           NaN                NaN                 NaN
# 2010-07-19           NaN                NaN                 NaN
# 2010-07-20           NaN                NaN                 NaN
# 2010-07-21           NaN                NaN                 NaN
# 2010-07-22           NaN                0.1                 0.1
#
#             BBANDS_lower_band  PSAR          EMA_7d_ET            HTTL_ET  \
# Date
# 2010-07-18                NaN   NaN  Mantener_posicion  Mantener_posicion
# 2010-07-19                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2010-07-20                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2010-07-21                NaN   0.1  Mantener_posicion  Mantener_posicion
# 2010-07-22                0.1   0.1  Mantener_posicion  Mantener_posicion
#
#                       PSAR_ET  Trend  Residuals  Comprar_EMA_7d_ET  \
# Date
# 2010-07-18  Mantener_posicion    NaN        NaN                  0
# 2010-07-19  Mantener_posicion    NaN        NaN                  0
# 2010-07-20  Mantener_posicion    NaN        NaN                  0
# 2010-07-21  Mantener_posicion    0.1 -19.575231                  0
# 2010-07-22  Mantener_posicion    0.1  15.128694                  0
#
#             Mantener_posicion_EMA_7d_ET  Vender_EMA_7d_ET  Comprar_HTTL_ET  \
# Date
# 2010-07-18                            1                 0                0
# 2010-07-19                            1                 0                0
# 2010-07-20                            1                 0                0
# 2010-07-21                            1                 0                0
# 2010-07-22                            1                 0                0
#
#             Mantener_posicion_HTTL_ET  Vender_HTTL_ET  Comprar_PSAR_ET  \
# Date
# 2010-07-18                          1               0                0
# 2010-07-19                          1               0                0
# 2010-07-20                          1               0                0
# 2010-07-21                          1               0                0
# 2010-07-22                          1               0                0
#
#             Mantener_posicion_PSAR_ET  Vender_PSAR_ET
# Date
# 2010-07-18                          1               0
# 2010-07-19                          1               0
# 2010-07-20                          1               0
# 2010-07-21                          1               0
# 2010-07-22                          1               0

# %% [markdown]
# Se eliminan las variables categóricas del BTC_ind_trend_2

# %%
BTC_ind_trend_2 = BTC_ind_trend_2.drop(["EMA_7d_ET", "HTTL_ET", "PSAR_ET"], axis=1)

# %%
BTC_ind_trend_2.columns
# Out:
# Index(['Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff', 'Target',
#        'EMA_7d', 'HT_TRENDLINE', 'BBANDS_upper_band', 'BBANDS_middle_band',
#        'BBANDS_lower_band', 'PSAR', 'Trend', 'Residuals', 'Comprar_EMA_7d_ET',
#        'Mantener_posicion_EMA_7d_ET', 'Vender_EMA_7d_ET', 'Comprar_HTTL_ET',
#        'Mantener_posicion_HTTL_ET', 'Vender_HTTL_ET', 'Comprar_PSAR_ET',
#        'Mantener_posicion_PSAR_ET', 'Vender_PSAR_ET'],
#       dtype='object')

# %% [markdown]
# Se elimina el registro NaN de la variable [Target] dado que los modelos no pueden procesar este tipo de datos

# %%
BTC_ind_trend_2 = BTC_ind_trend_2 [0:4385]

# %%
BTC_ind_trend_2.isnull().sum()
# Out:
# Price                           0
# Open                            0
# High                            0
# Low                             0
# Vol.                            0
# Percentage_diff                 0
# Target                          0
# EMA_7d                          6
# HT_TRENDLINE                   63
# BBANDS_upper_band               4
# BBANDS_middle_band              4
# BBANDS_lower_band               4
# PSAR                            1
# Trend                           5
# Residuals                       5
# Comprar_EMA_7d_ET               0
# Mantener_posicion_EMA_7d_ET     0
# Vender_EMA_7d_ET                0
# Comprar_HTTL_ET                 0
# Mantener_posicion_HTTL_ET       0
# Vender_HTTL_ET                  0
# Comprar_PSAR_ET                 0
# Mantener_posicion_PSAR_ET       0
# Vender_PSAR_ET                  0
# dtype: int64

# %%
BTC_ind_trend_2 = BTC_ind_trend_2.dropna()

# %%
BTC_ind_trend_2.isnull().sum()
# Out:
# Price                          0
# Open                           0
# High                           0
# Low                            0
# Vol.                           0
# Percentage_diff                0
# Target                         0
# EMA_7d                         0
# HT_TRENDLINE                   0
# BBANDS_upper_band              0
# BBANDS_middle_band             0
# BBANDS_lower_band              0
# PSAR                           0
# Trend                          0
# Residuals                      0
# Comprar_EMA_7d_ET              0
# Mantener_posicion_EMA_7d_ET    0
# Vender_EMA_7d_ET               0
# Comprar_HTTL_ET                0
# Mantener_posicion_HTTL_ET      0
# Vender_HTTL_ET                 0
# Comprar_PSAR_ET                0
# Mantener_posicion_PSAR_ET      0
# Vender_PSAR_ET                 0
# dtype: int64

# %%
BTC_ind_trend_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4320 entries, 2010-09-19 to 2022-07-17
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Price                        4320 non-null   float64
#  1   Open                         4320 non-null   float64
#  2   High                         4320 non-null   float64
#  3   Low                          4320 non-null   float64
#  4   Vol.                         4320 non-null   float64
#  5   Percentage_diff              4320 non-null   float64
#  6   Target                       4320 non-null   float64
#  7   EMA_7d                       4320 non-null   float64
#  8   HT_TRENDLINE                 4320 non-null   float64
#  9   BBANDS_upper_band            4320 non-null   float64
#  10  BBANDS_middle_band           4320 non-null   float64
#  11  BBANDS_lower_band            4320 non-null   float64
#  12  PSAR                         4320 non-null   float64
#  13  Trend                        4320 non-null   float64
#  14  Residuals                    4320 non-null   float64
#  15  Comprar_EMA_7d_ET            4320 non-null   uint8
#  16  Mantener_posicion_EMA_7d_ET  4320 non-null   uint8
#  17  Vender_EMA_7d_ET             4320 non-null   uint8
#  18  Comprar_HTTL_ET              4320 non-null   uint8
#  19  Mantener_posicion_HTTL_ET    4320 non-null   uint8
#  20  Vender_HTTL_ET               4320 non-null   uint8
#  21  Comprar_PSAR_ET              4320 non-null   uint8
#  22  Mantener_posicion_PSAR_ET    4320 non-null   uint8
#  23  Vender_PSAR_ET               4320 non-null   uint8
# dtypes: float64(15), uint8(9)
# memory usage: 578.0+ KB

# %% [markdown]
# # Modelado (Random forest)

# %% [markdown]
# **...Recordando que...**
#
# *Objetivo general del proyecto*
#
# I.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) el dinamismo del precio de Bitcoin en el corto plazo, es decir, si el precio de este criptoactivo subirá o bajará en la temporalidad estudiada (1 día).
#
# **...Recordando que...**
#
# *Objetivo específico del proyecto*
#
# III.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) y a corto plazo, el movimiento alcista o bajista del precio de BTC.

# %% [markdown]
# **Explicación**:
#
# En lo que sigue se procederá a realizar varios modelos supervisados de clasificación de tipo "Random forest".
#
# Estos serán configurados con diversos hiperparámetros a fin de encontrar el resultado más óptimo para este data set.
#
# La variable target del modelo es la columna [Target] de BTC_ind_trend_2.

# %% [markdown]
# ## Modelo 1

# %%
# Se separa X e y
X = BTC_ind_trend_2.drop(["Target"], axis=1)
y = BTC_ind_trend_2["Target"]

# %%
# Se separa la data en train (70%) y test (30%)
# Se decide aplicar stratify
(X_train, X_test, y_train, y_test) = train_test_split(X, y,
                                        stratify=y,
                                        test_size=0.30,
                                        random_state=11)

# %%
# Se crea el Random forest
model = RandomForestClassifier(random_state=11, n_estimators=200,
                               class_weight="balanced", max_features="log2")

# %%
# Se entrena al Random forest
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        n_estimators=200, random_state=11)

# %%
#Prediccion en Train

y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0

# %%
# Se busca conocer el grado de prediccion del modelo utilizando el Test
y_test_pred = model.predict(X_test)

# %%
# Se calcula el accuracy en Test
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación es:',test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación es: 0.6558641975308642

# %% [markdown]
# Observaciones:
#
# - Dado que el % de aciertos en el set de entrenamiento es 1.0 y el % de aciertos en el set de evaluación es 65,6 se entiende que hay overfitting. Para corregirlo se intentará modificar algunos hiperparámetros.

# %% [markdown]
# ## Modelo 2

# %%
# Se crea un nuevo Random forest con otros hiperparámetros
model = RandomForestClassifier(random_state=11,
                               n_estimators=100,
                               class_weight="balanced", 
                               max_features="log2")
model.fit(X_train, y_train)

#Prediccion en Train
y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

#Prediccion en Test
y_test_pred = model.predict(X_test) 
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación: 0.6574074074074074

# %% [markdown]
# Observaciones:
#
# - Las modificaciones realizadas no generaron una reducción de la diferencia significativa entre el % de aciertos en el set de entrenamiento y el % de aciertos en el set de evaluación. Se utilizará RandomizedSearchCV a fin de intentar mejor el resultado.

# %% [markdown]
# ## Hyperparameter tuning

# %%
# Se instancia el modelo
random_forest = RandomForestClassifier()

# %%
from sklearn.model_selection import RandomizedSearchCV

# Se definen los parámetros de búsqueda
params = {'random_state': np.arange(1,10000,10),
    'n_estimators': [100, 200, 500,1000,10000],
    'max_depth': [1,2,3],
    'class_weight':['balanced'], 
    'max_features': ['log2']}

grid_random_forest = RandomizedSearchCV(random_forest, params, scoring = 'neg_mean_absolute_error', n_iter=100, cv=5, verbose=2)

# %%
# Se entrena el modelo
grid_random_forest.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2821; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2821; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2821; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2821; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=2821; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6731; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6731; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6731; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6731; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6731; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=4211; total time=  22.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=4211; total time=  22.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=4211; total time=  23.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=4211; total time=  22.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=4211; total time=  22.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3911; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3911; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3911; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3911; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=3911; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=3111; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6001; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6001; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6001; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6001; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6001; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=361; total time=  23.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=361; total time=  23.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=361; total time=  24.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=361; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=361; total time=  22.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=511; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=511; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=511; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=511; total time=   3.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=511; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=941; total time=  18.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=941; total time=  18.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=941; total time=  18.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=941; total time=  19.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=941; total time=  18.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6951; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6951; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6951; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6951; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6951; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3081; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3081; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4971; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5121; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5121; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5121; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5121; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=5121; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4441; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4441; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4441; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4441; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=4441; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4591; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4591; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4591; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4591; total time=   1.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=4591; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4681; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4681; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4681; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4681; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4681; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3871; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3871; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3871; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3871; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3871; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2731; total time=   2.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2731; total time=   2.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2731; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2731; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=2731; total time=   2.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7931; total time=  19.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7931; total time=  18.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7931; total time=  19.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7931; total time=  18.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7931; total time=  18.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1541; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1541; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1541; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9451; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9451; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9451; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9451; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9451; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8271; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8271; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8271; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8271; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=8271; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=491; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=491; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=491; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=491; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=491; total time=   1.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=8921; total time=  27.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=8921; total time=  26.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=8921; total time=  27.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=8921; total time=  26.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=8921; total time=  26.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8851; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=9461; total time=  23.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=9461; total time=  22.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=9461; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=9461; total time=  23.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=9461; total time=  22.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5801; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5801; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5801; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5801; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=5801; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7651; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7651; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7651; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7651; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=7651; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8821; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8821; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8821; total time=   3.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8821; total time=   4.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=8821; total time=   4.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5411; total time=  48.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5411; total time=  46.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5411; total time=  39.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5411; total time=  29.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5411; total time=  31.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7151; total time=  20.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7151; total time=  19.6s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7151; total time=  24.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7151; total time=  24.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=7151; total time=  21.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1311; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1311; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1311; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1311; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=1311; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7131; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7131; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=7131; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=1201; total time=  24.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=1201; total time=  23.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=1201; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=1201; total time=  22.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=1201; total time=  23.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3541; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3541; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3541; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3541; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3541; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4181; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4181; total time=   2.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4181; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4181; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=4181; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5601; total time=  29.9s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5601; total time=  27.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5601; total time=  28.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5601; total time=  25.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5601; total time=  25.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7481; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7481; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7481; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7481; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=7481; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=3991; total time=  31.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=3991; total time=  30.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=3991; total time=  31.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=3991; total time=  26.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=3991; total time=  27.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6371; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6371; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6371; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6371; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6371; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5031; total time=  26.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5031; total time=  27.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5031; total time=  26.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5031; total time=  26.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=5031; total time=  26.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=881; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=881; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=881; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=881; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=881; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8771; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8771; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8771; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8771; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8771; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7451; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7451; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7451; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7451; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7451; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1191; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1191; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1191; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1191; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=1191; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9051; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9051; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9051; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9051; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9051; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9491; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9491; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9491; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9491; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=200, random_state=9491; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=61; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=61; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=61; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=61; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=61; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3881; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3881; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3881; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3881; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=3881; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2311; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2311; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2311; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2311; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2311; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=641; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=641; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=641; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=641; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=641; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4481; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4481; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4481; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4481; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4481; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8691; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8691; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8691; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8691; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=8691; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3841; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3841; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3841; total time=   3.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3841; total time=   2.9s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3841; total time=   2.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=551; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=551; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=551; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=551; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=551; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=6481; total time=  26.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=6481; total time=  26.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=6481; total time=  27.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=6481; total time=  26.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=6481; total time=  27.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5441; total time=  18.5s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5441; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5441; total time=  18.7s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5441; total time=  18.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5441; total time=  18.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8941; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8941; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8941; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8941; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=8941; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3751; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3751; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3751; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3751; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=3751; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7061; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7061; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7061; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7061; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7061; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4961; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4961; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4961; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4961; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=4961; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7041; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7041; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7041; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7041; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7041; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=1331; total time=  26.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=1331; total time=  26.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=1331; total time=  27.0s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=1331; total time=  26.8s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=10000, random_state=1331; total time=  27.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=921; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=921; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=921; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=921; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=921; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2971; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2971; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2971; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2971; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2971; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=9541; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=2951; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=2951; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=2951; total time=  19.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=2951; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=2951; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4481; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9791; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9791; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9791; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9791; total time=   0.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=9791; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6101; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6101; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6101; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6101; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=6101; total time=   2.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=251; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=251; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=251; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=251; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=251; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2291; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2291; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2291; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2291; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=200, random_state=2291; total time=   0.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2761; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2761; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2761; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2761; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=2761; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3151; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3151; total time=   1.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3151; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3151; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=1000, random_state=3151; total time=   1.7s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8251; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8251; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8251; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8251; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=500, random_state=8251; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2101; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2101; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2101; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2101; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=2101; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=8001; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=8001; total time=   0.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=8001; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=8001; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=8001; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8271; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8271; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8271; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8271; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=100, random_state=8271; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4681; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4681; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4681; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4681; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=4681; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4701; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4701; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4701; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4701; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=4701; total time=   2.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7691; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7691; total time=   2.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7691; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7691; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=7691; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=1631; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=1631; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=1631; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=1631; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=1631; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=9391; total time=   1.0s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=6261; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=6261; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=6261; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=6261; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=6261; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5531; total time=  22.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5531; total time=  23.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5531; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5531; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=5531; total time=  23.3s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4111; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4111; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4111; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4111; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=4111; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7611; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7611; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7611; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7611; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=500, random_state=7611; total time=   0.8s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=7451; total time=  22.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=7451; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=7451; total time=  23.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=7451; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=7451; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3141; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3141; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3141; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3141; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=3141; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6201; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6201; total time=   1.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6201; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6201; total time=   1.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=500, random_state=6201; total time=   1.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5581; total time=  18.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5581; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5581; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5581; total time=  18.9s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=5581; total time=  18.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3821; total time=  22.7s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3821; total time=  23.0s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3821; total time=  22.4s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3821; total time=  22.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3821; total time=  23.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1551; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1551; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1551; total time=   2.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1551; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=1000, random_state=1551; total time=   2.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3371; total time=  22.5s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3371; total time=  23.6s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3371; total time=  22.2s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3371; total time=  22.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=10000, random_state=3371; total time=  23.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=9801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=9801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=9801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=9801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=100, random_state=9801; total time=   0.2s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=551; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=551; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=551; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=551; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=200, random_state=551; total time=   0.4s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=4461; total time=  18.2s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=4461; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=4461; total time=  18.7s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=4461; total time=  19.1s
# [CV] END class_weight=balanced, max_depth=1, max_features=log2, n_estimators=10000, random_state=4461; total time=  18.3s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=8561; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=8561; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=8561; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=8561; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=2, max_features=log2, n_estimators=100, random_state=8561; total time=   0.1s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3071; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3071; total time=   2.5s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3071; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3071; total time=   2.6s
# [CV] END class_weight=balanced, max_depth=3, max_features=log2, n_estimators=1000, random_state=3071; total time=   2.6s
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    param_distributions={'class_weight': ['balanced'],
#                                         'max_depth': [1, 2, 3],
#                                         'max_features': ['log2'],
#                                         'n_estimators': [100, 200, 500, 1000,
#                                                          10000],
#                                         'random_state': array([   1,   11,   21,   31,   41,   51,   61,   71,   81,   91,  101,
#         111,  121,  131,  141,  151,  161,  171,  181,  191,  201,  211,
#         221,  231,  241,  251,  261,  271,  281,  291,  301,  311,  321,
#         331,...
#        9351, 9361, 9371, 9381, 9391, 9401, 9411, 9421, 9431, 9441, 9451,
#        9461, 9471, 9481, 9491, 9501, 9511, 9521, 9531, 9541, 9551, 9561,
#        9571, 9581, 9591, 9601, 9611, 9621, 9631, 9641, 9651, 9661, 9671,
#        9681, 9691, 9701, 9711, 9721, 9731, 9741, 9751, 9761, 9771, 9781,
#        9791, 9801, 9811, 9821, 9831, 9841, 9851, 9861, 9871, 9881, 9891,
#        9901, 9911, 9921, 9931, 9941, 9951, 9961, 9971, 9981, 9991])},
#                    scoring='neg_mean_absolute_error', verbose=2)

# %%
# Se obtiene el mejor modelo
grid_random_forest.best_estimator_
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=1,
#                        max_features='log2', random_state=4971)

# %%
# Predicción de casos nuevos
grid_random_forest.predict(X_train)
grid_random_forest.predict(X_test)
# Out:
# array([0., 1., 1., ..., 1., 0., 1.])

# %%
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 1.0
# % de aciertos sobre el set de evaluación: 0.6574074074074074

# %% [markdown]
# Observación:
#
# - El Random Forest no mejoró el overfitting anterior.
# - En el mejor de los casos se obtuvo 0.657 de aciertos de valores futuros.

# %%
# Se crea un nuevo Random forest con otros hiperparámetros (se agrega balance a los datos del mejor modelos anterior)
model = RandomForestClassifier(random_state=4971,
                               n_estimators=200,
                               class_weight="balanced", 
                               max_features="log2",
                               max_depth=1)
model.fit(X_train, y_train)

#Prediccion en Train
y_train_pred = model.predict(X_train) 
train_accuracy = accuracy_score(y_train, y_train_pred)

print('% de aciertos sobre el set de entrenamiento:',train_accuracy)

#Prediccion en Test
y_test_pred = model.predict(X_test) 
test_accuracy = accuracy_score(y_test, y_test_pred)

print('% de aciertos sobre el set de evaluación:',test_accuracy)
# Out:
# % de aciertos sobre el set de entrenamiento: 0.6636904761904762
# % de aciertos sobre el set de evaluación: 0.6651234567901234

# %% [markdown]
# Observaciones:
# - El parámetro class_weight="balanced" resolvió el overfitting pero no la capacidad de predicción del modelo.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# Predicciones
predictions = model.predict(X_test)

#Matriz de Confusión
print(confusion_matrix(y_test, predictions))

#Ploteamos la Matriz
plot_confusion_matrix(model, X_test, y_test)
plt.show()
# Out:
# [[486 174]
#  [260 376]]

# %% [markdown]
# Observaciones:
# - Al modelo le cuesta encontrar las clases (un número alto de falsos positivos y negativos).

# %%
# Accuracy
print(f"Accuracy of the classifier is: {accuracy_score(y_test, predictions)}")

# Precision
from sklearn.metrics import precision_score
print(f"Precision Score of the classifier is: {precision_score(y_test, predictions)}")

# Recall
from sklearn.metrics import recall_score
print(f"Recall Score of the classifier is: {recall_score(y_test, predictions)}")

# Calculo del F1 score
from sklearn.metrics import f1_score
print(f"F1 Score of the classifier is: {f1_score(y_test, predictions)}")

#Template CURVA - ROC

from sklearn.metrics import roc_curve, auc

class_probabilities = model.predict_proba(X_test)
preds = class_probabilities[:, 1]

fpr, tpr, threshold = roc_curve(y_test, preds)
roc_auc = auc(fpr, tpr)

# AUC
print(f"AUC for our classifier is: {roc_auc}")

# Gráfica de la Curva ROC
plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()
# Out:
# Accuracy of the classifier is: 0.6651234567901234
# Precision Score of the classifier is: 0.6836363636363636
# Recall Score of the classifier is: 0.5911949685534591
# F1 Score of the classifier is: 0.6340640809443507
# AUC for our classifier is: 0.7061249285305888

# %% [markdown]
# Observaciones:
# - Es un modelo que le cuesta detectar las clases (en comparación con los Decision Trees).
