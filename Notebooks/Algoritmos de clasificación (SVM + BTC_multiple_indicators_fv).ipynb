# %% [markdown]
# # Fecha de entrega: 27/08/2022 (corresponde a clase 20)

# %% [markdown]
# # Algoritmo de clasificación: Support Vector Machine

# %% [markdown]
# # Diccionario

# %% [markdown]
# **BTC_multiple_indicators_fv**
#
# - Date: fecha en YYYY-MM-DD (object)
# - Price: precio de cierre de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Open: precio de apertura de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - High: precio más alto de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Low: precio más bajo de BTC en el día de la fecha (USD) (float) (Variable numérica continua)
# - Vol.: volumen de BTC (Número de intercambios) en el día de la fecha (float) (Variable numérica continua)
# - Percentage_diff: diferencia porcentual del precio de BTC en la fecha [x+1] con respecto a la fecha [x] (float) (Variable numérica continua)
# - Target: 1 indica que en el día de la fecha el precio de BTC subió, y 0 que el precio bajó (float) (Se la tratará como variable categórica)
# - ADOSC: indica la fuerza de los movimientos de precios y la presión subyacente de compra y venta (float) (Variable numérica continua)
# - HT_DCPHASE: Hilbert Transform - Dominant Cycle Phase (fase del ciclo dominante en una barra específica entre 0 a 360 grados dentro del período de transformada de Hilbert actual medido instantáneamente en esa barra) (grados) (float) (Variable numérica continua)
# - HT_SINE_sine: Hilbert Transform - SineWave (-1 a 1) (float) (Variable numérica continua)
# - HT_PHASOR_leadsine: Hilbert Transform seno del lead (-1 a 1) (float) (Variable numérica continua)
# - ATR: valores del indicador Average True Range (Promedio de Rango Verdadero) (float) (Variable numérica continua)
# - Linearregression: precio estimado por regresión lineal (USD) (float) (Variable numérica continua)
# - Linearangle: ángulo de la mejor línea de regresión (ángulos) (float) (Variable numérica continua)
# - Linearintercept: intercepción de la regresión lineal (USD) (float) (Variable numérica continua)
# - Linearslope: curvatura de la regresión lineal (grados) (float) (Variable numérica continua)
# - VAR: varianza (medida de dispersión definida como la esperanza del cuadrado de la desviación de dicha variable respecto a su media) (float) (Variable numérica continua)
# - STDDEV: desviación estándar (medición de la dispersión de los datos) (float) (Variable numérica continua)
# - Trend: tendencia de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)
# - Seasonality: estacionariedad de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)
# - Residuals: residualidad de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)
# - BTC_cycle: ciclicidad de la variable [Price] a lo largo de la serie de tiempo (float) (Variable numérica continua)

# %% [markdown]
# # Librerías

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import plotly.express as px
import seaborn as sns
import pandas_profiling
import statsmodels.api as sm
from pandas.plotting import lag_plot
from statsmodels.graphics.tsaplots import plot_acf
from matplotlib.cm import ScalarMappable

from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
sns.set_style('darkgrid')

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
# Out:
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\lucia\anaconda3\envs\acjup\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,

# %% [markdown]
# # Data acquisition

# %%
def gdriveColabPath(sharing_url):
  file_id=sharing_url.split('/')[-2]
  dwn_url='https://drive.google.com/uc?id=' + file_id
  return dwn_url

# %% [markdown]
# ## Adquiriendo BTC_multiple_indicators_fv

# %%
# Se carga la base de datos de BTC_multiple_indicators_fv desde la carpeta compartida en el Google Drive
sharing_url = "https://drive.google.com/file/d/17dwqcGhoYCqLE5HWcu7TVT8lWB4lAjjT/view?usp=sharing"

# %%
dwn_url=gdriveColabPath(sharing_url)
BTC_multiple_indicators_fv_df = pd.read_csv(dwn_url, sep=";", decimal=".")
BTC_multiple_indicators_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  ADOSC  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0       0    NaN
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0       0    NaN
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0       0    NaN
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0       0    NaN
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0       0    NaN
#
#    ATR  Linearregression  Linearangle  Linearintercept  Linearslope  VAR  \
# 0  NaN               NaN          NaN              NaN          NaN  NaN
# 1  NaN               NaN          NaN              NaN          NaN  NaN
# 2  NaN               NaN          NaN              NaN          NaN  NaN
# 3  NaN               NaN          NaN              NaN          NaN  NaN
# 4  NaN               NaN          NaN              NaN          NaN  0.0
#
#    STDDEV  HT_DCPHASE  HT_SINE_sine  HT_PHASOR_leadsine  Trend  Seasonality  \
# 0     NaN         NaN           NaN                 NaN    NaN    -3.979105
# 1     NaN         NaN           NaN                 NaN    NaN     8.917886
# 2     NaN         NaN           NaN                 NaN    NaN     1.150686
# 3     NaN         NaN           NaN                 NaN    0.1    19.575231
# 4     0.0         NaN           NaN                 NaN    0.1   -15.128694
#
#    Residuals     BTC_cycle
# 0        NaN -1.869639e-06
# 1        NaN -1.538597e-06
# 2        NaN -1.206386e-06
# 3 -19.575231 -8.708768e-07
# 4  15.128694 -5.291847e-07

# %% [markdown]
# # Data wrangling

# %% [markdown]
# ## Análisis pre-modelado

# %%
# Registros y columnas
BTC_multiple_indicators_fv_df.shape
# Out:
# (4386, 23)

# %%
# Nombre de columnas
BTC_multiple_indicators_fv_df.columns
# Out:
# Index(['Date', 'Price', 'Open', 'High', 'Low', 'Vol.', 'Percentage_diff',
#        'Target', 'ADOSC', 'ATR', 'Linearregression', 'Linearangle',
#        'Linearintercept', 'Linearslope', 'VAR', 'STDDEV', 'HT_DCPHASE',
#        'HT_SINE_sine', 'HT_PHASOR_leadsine', 'Trend', 'Seasonality',
#        'Residuals', 'BTC_cycle'],
#       dtype='object')

# %%
# Tipos de datos de las variables
BTC_multiple_indicators_fv_df.dtypes
# Out:
# Date                   object
# Price                 float64
# Open                  float64
# High                  float64
# Low                   float64
# Vol.                  float64
# Percentage_diff       float64
# Target                  int64
# ADOSC                 float64
# ATR                   float64
# Linearregression      float64
# Linearangle           float64
# Linearintercept       float64
# Linearslope           float64
# VAR                   float64
# STDDEV                float64
# HT_DCPHASE            float64
# HT_SINE_sine          float64
# HT_PHASOR_leadsine    float64
# Trend                 float64
# Seasonality           float64
# Residuals             float64
# BTC_cycle             float64
# dtype: object

# %%
# Columnas y cantidad de registros
BTC_multiple_indicators_fv_df.count()
# Out:
# Date                  4386
# Price                 4386
# Open                  4386
# High                  4386
# Low                   4386
# Vol.                  4386
# Percentage_diff       4386
# Target                4386
# ADOSC                 4377
# ATR                   4372
# Linearregression      4373
# Linearangle           4373
# Linearintercept       4373
# Linearslope           4373
# VAR                   4382
# STDDEV                4382
# HT_DCPHASE            4323
# HT_SINE_sine          4323
# HT_PHASOR_leadsine    4323
# Trend                 4380
# Seasonality           4386
# Residuals             4380
# BTC_cycle             4386
# dtype: int64

# %%
# Valores NaN
BTC_multiple_indicators_fv_df.isnull().sum()
# Out:
# Date                   0
# Price                  0
# Open                   0
# High                   0
# Low                    0
# Vol.                   0
# Percentage_diff        0
# Target                 0
# ADOSC                  9
# ATR                   14
# Linearregression      13
# Linearangle           13
# Linearintercept       13
# Linearslope           13
# VAR                    4
# STDDEV                 4
# HT_DCPHASE            63
# HT_SINE_sine          63
# HT_PHASOR_leadsine    63
# Trend                  6
# Seasonality            0
# Residuals              6
# BTC_cycle              0
# dtype: int64

# %%
BTC_multiple_indicators_fv_df.head()
# Out:
#          Date  Price  Open  High  Low    Vol.  Percentage_diff  Target  ADOSC  \
# 0  2010-07-18    0.1   0.0   0.1  0.1    80.0              0.0       0    NaN
# 1  2010-07-19    0.1   0.1   0.1  0.1   570.0              0.0       0    NaN
# 2  2010-07-20    0.1   0.1   0.1  0.1   260.0              0.0       0    NaN
# 3  2010-07-21    0.1   0.1   0.1  0.1   580.0              0.0       0    NaN
# 4  2010-07-22    0.1   0.1   0.1  0.1  2160.0              0.0       0    NaN
#
#    ATR  Linearregression  Linearangle  Linearintercept  Linearslope  VAR  \
# 0  NaN               NaN          NaN              NaN          NaN  NaN
# 1  NaN               NaN          NaN              NaN          NaN  NaN
# 2  NaN               NaN          NaN              NaN          NaN  NaN
# 3  NaN               NaN          NaN              NaN          NaN  NaN
# 4  NaN               NaN          NaN              NaN          NaN  0.0
#
#    STDDEV  HT_DCPHASE  HT_SINE_sine  HT_PHASOR_leadsine  Trend  Seasonality  \
# 0     NaN         NaN           NaN                 NaN    NaN    -3.979105
# 1     NaN         NaN           NaN                 NaN    NaN     8.917886
# 2     NaN         NaN           NaN                 NaN    NaN     1.150686
# 3     NaN         NaN           NaN                 NaN    0.1    19.575231
# 4     0.0         NaN           NaN                 NaN    0.1   -15.128694
#
#    Residuals     BTC_cycle
# 0        NaN -1.869639e-06
# 1        NaN -1.538597e-06
# 2        NaN -1.206386e-06
# 3 -19.575231 -8.708768e-07
# 4  15.128694 -5.291847e-07

# %% [markdown]
# Observaciones:
#
# Se observaron varios registros NaN en "BTC_multiple_indicators_fv.csv".
#
# Esto implica la necesidad de tomar una decisión con respecto a este tipo de valores (instancia previa al modelado).
#
# Se descarta rellenar los NaN con promedios de valores previos y/o posteriores por varias razones:
#
# 1. En las variables [Trend] y [Residuals], 3 de los 6 valores NaN se encuentran al principio de la serie, y los restantes 3 al final de la misma. Esto significa que no se puede hacer un promedio con valores anteriores y posteriores a los valores NaN sino solo con anteriores o posteriores según el caso. Proceder con un promedio con los datos anteriores o posteriores en una serie de tiempo supone un problema extra (¿cuántos valores hacia atrás o hacia adelante se deben tomar?, ¿cuál es el grado de autocorrelación con los valores anteriores o posteriores?, entre otros).
#
#
# 2. En la variable [Residuals] hay valores positivos y negativos en los registros anteriores y posteriores inmediatos según el caso. Esto también añade un problema extra (¿qué signo se debería utilizar si se rellenan esos casilleros?).
#
#
# 3. Al no tratarse de un problema de regresión lineal del valor que tomaría el precio de BTC en el registro siguiente sino un problema de clasificación, la eliminación de los valores NaN no afectaría en demasía la predicción del modelo a pesar de la autocorrelación referida en el punto 2. Si se considera eliminar los 12 registros NaN (6 en [Residual] y 6 en [Trend] ) se estaría solamente eliminando un (6*100/4386 =) 0.136 % de los datos.
#
# 4. En el resto de los casos los valores NaN (tal como fue explicado oportunamente en cada notebook) se debe a la fórmula que se utilizó para calcular cada una de las variables.
#
# Dado que el modelo no acepta valores NaN por lo dicho arriba y en documentos de trabajo anteriores, se procede a su eliminación dado que solo representan al (63*100/4386) 1.44 % de los valores del data set.

# %% [markdown]
# ## Ultimas manipulaciones pre-modelado

# %% [markdown]
# Se reindexa el data set que se modelará a fin de que la variable [Date] funcione como nuevo índice de la base de datos.

# %%
# Se crea una copia de BTC_multiple_indicators_fv_df con nombre BTC_multiple y se la reindexa con la variable [Date] como nuevo índice
BTC_multiple = BTC_multiple_indicators_fv_df.set_index("Date")

# %%
BTC_multiple.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target          ADOSC          ATR  Linearregression  Linearangle  \
# Date
# 2022-07-16       1   38511.511976  1166.898729      20802.237143    88.315816
# 2022-07-17       0    7776.544982  1147.777391      20673.194286   -64.096744
# 2022-07-18       1   66185.614950  1204.671863      21078.882857    88.362015
# 2022-07-19       1  150988.804515  1274.016730      21643.817143    89.338511
# 2022-07-20       0  152531.617704  1216.158392      22101.408571    89.554376
#
#             Linearintercept  Linearslope           VAR       STDDEV  \
# Date
# 2022-07-16     20360.105714    34.010110  4.057132e+05   636.956216
# 2022-07-17     20699.962857    -2.059121  9.871333e+04   314.186781
# 2022-07-18     20624.274286    34.969890  4.892406e+05   699.457371
# 2022-07-19     20517.854286    86.612527  1.087067e+06  1042.625182
# 2022-07-20     20429.977143   128.571648  1.090209e+06  1044.130891
#
#             HT_DCPHASE  HT_SINE_sine  HT_PHASOR_leadsine         Trend  \
# Date
# 2022-07-16  188.760909     -0.152312           -0.806557  21370.371429
# 2022-07-17  208.648545     -0.479436           -0.959553  21784.528571
# 2022-07-18  217.212389     -0.604771           -0.990777           NaN
# 2022-07-19  222.679567     -0.677898           -0.999180           NaN
# 2022-07-20  170.267628      0.169046           -0.577396           NaN
#
#             Seasonality   Residuals    BTC_cycle
# Date
# 2022-07-16    -0.183737 -160.287691  -154.061979
# 2022-07-17    -3.979105 -994.949467  -745.841392
# 2022-07-18     8.917886         NaN   822.393782
# 2022-07-19     1.150686         NaN  1532.500614
# 2022-07-20    19.575231         NaN  1096.422183

# %% [markdown]
# Dado que en la práctica real solo se tiene hasta los valores del registro anterior al que se quiere predecir se intenta hacer un shift (-1) a la variable [Target]. Se entiende que así (en caso de que el modelo prediga con previsibilidad suficiente) se podría estar seguro de que después vendría el valor de [Target] original sin shift (-1).

# %%
# Se genera un back up
BTC_multiple_2 = BTC_multiple.copy()

# %%
# Se realiza el shift 
BTC_multiple_2 ["Target"] = BTC_multiple ["Target"].shift(-1)

# %%
BTC_multiple_2.tail()
# Out:
#               Price     Open     High      Low      Vol.  Percentage_diff  \
# Date
# 2022-07-16  21209.9  20825.2  21561.3  20484.4  136890.0             1.85
# 2022-07-17  20785.6  21209.8  21654.4  20755.2  132810.0            -2.00
# 2022-07-18  22525.8  20785.6  22714.9  20770.6  279720.0             8.37
# 2022-07-19  23410.2  22529.3  23757.3  21581.8  308910.0             3.93
# 2022-07-20  23149.1  23412.0  23429.9  22965.9  290210.0            -1.12
#
#             Target          ADOSC          ATR  Linearregression  Linearangle  \
# Date
# 2022-07-16     0.0   38511.511976  1166.898729      20802.237143    88.315816
# 2022-07-17     1.0    7776.544982  1147.777391      20673.194286   -64.096744
# 2022-07-18     1.0   66185.614950  1204.671863      21078.882857    88.362015
# 2022-07-19     0.0  150988.804515  1274.016730      21643.817143    89.338511
# 2022-07-20     NaN  152531.617704  1216.158392      22101.408571    89.554376
#
#             Linearintercept  Linearslope           VAR       STDDEV  \
# Date
# 2022-07-16     20360.105714    34.010110  4.057132e+05   636.956216
# 2022-07-17     20699.962857    -2.059121  9.871333e+04   314.186781
# 2022-07-18     20624.274286    34.969890  4.892406e+05   699.457371
# 2022-07-19     20517.854286    86.612527  1.087067e+06  1042.625182
# 2022-07-20     20429.977143   128.571648  1.090209e+06  1044.130891
#
#             HT_DCPHASE  HT_SINE_sine  HT_PHASOR_leadsine         Trend  \
# Date
# 2022-07-16  188.760909     -0.152312           -0.806557  21370.371429
# 2022-07-17  208.648545     -0.479436           -0.959553  21784.528571
# 2022-07-18  217.212389     -0.604771           -0.990777           NaN
# 2022-07-19  222.679567     -0.677898           -0.999180           NaN
# 2022-07-20  170.267628      0.169046           -0.577396           NaN
#
#             Seasonality   Residuals    BTC_cycle
# Date
# 2022-07-16    -0.183737 -160.287691  -154.061979
# 2022-07-17    -3.979105 -994.949467  -745.841392
# 2022-07-18     8.917886         NaN   822.393782
# 2022-07-19     1.150686         NaN  1532.500614
# 2022-07-20    19.575231         NaN  1096.422183

# %% [markdown]
# Se elimina el registro NaN de la variable [Target] dado que los modelos no pueden procesar este tipo de datos

# %%
BTC_multiple_2 = BTC_multiple_2 [0:4385]

# %%
BTC_multiple_2.isnull().sum()
# Out:
# Price                  0
# Open                   0
# High                   0
# Low                    0
# Vol.                   0
# Percentage_diff        0
# Target                 0
# ADOSC                  9
# ATR                   14
# Linearregression      13
# Linearangle           13
# Linearintercept       13
# Linearslope           13
# VAR                    4
# STDDEV                 4
# HT_DCPHASE            63
# HT_SINE_sine          63
# HT_PHASOR_leadsine    63
# Trend                  5
# Seasonality            0
# Residuals              5
# BTC_cycle              0
# dtype: int64

# %% [markdown]
# Se eliminan los valores NaN del resto de las columnas.

# %%
BTC_multiple_2 = BTC_multiple_2.dropna()

# %%
BTC_multiple_2.isnull().sum()
# Out:
# Price                 0
# Open                  0
# High                  0
# Low                   0
# Vol.                  0
# Percentage_diff       0
# Target                0
# ADOSC                 0
# ATR                   0
# Linearregression      0
# Linearangle           0
# Linearintercept       0
# Linearslope           0
# VAR                   0
# STDDEV                0
# HT_DCPHASE            0
# HT_SINE_sine          0
# HT_PHASOR_leadsine    0
# Trend                 0
# Seasonality           0
# Residuals             0
# BTC_cycle             0
# dtype: int64

# %%
BTC_multiple_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4320 entries, 2010-09-19 to 2022-07-17
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Price               4320 non-null   float64
#  1   Open                4320 non-null   float64
#  2   High                4320 non-null   float64
#  3   Low                 4320 non-null   float64
#  4   Vol.                4320 non-null   float64
#  5   Percentage_diff     4320 non-null   float64
#  6   Target              4320 non-null   float64
#  7   ADOSC               4320 non-null   float64
#  8   ATR                 4320 non-null   float64
#  9   Linearregression    4320 non-null   float64
#  10  Linearangle         4320 non-null   float64
#  11  Linearintercept     4320 non-null   float64
#  12  Linearslope         4320 non-null   float64
#  13  VAR                 4320 non-null   float64
#  14  STDDEV              4320 non-null   float64
#  15  HT_DCPHASE          4320 non-null   float64
#  16  HT_SINE_sine        4320 non-null   float64
#  17  HT_PHASOR_leadsine  4320 non-null   float64
#  18  Trend               4320 non-null   float64
#  19  Seasonality         4320 non-null   float64
#  20  Residuals           4320 non-null   float64
#  21  BTC_cycle           4320 non-null   float64
# dtypes: float64(22)
# memory usage: 776.2+ KB

# %% [markdown]
# # Modelado (SVM)

# %% [markdown]
# **...Recordando que...**
#
# *Objetivo general del proyecto*
#
# I.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) el dinamismo del precio de Bitcoin en el corto plazo, es decir, si el precio de este criptoactivo subirá o bajará en la temporalidad estudiada (1 día).
#
# **...Recordando que...**
#
# *Objetivo específico del proyecto*
#
# III.	Diseñar diversos modelos de machine learning capaces de predecir con cierto grado de previsibilidad positiva (>50/55%) y a corto plazo, el movimiento alcista o bajista del precio de BTC.

# %% [markdown]
# **Explicación**:
#
# En lo que sigue se procederá a realizar varios modelos supervisados de clasificación de tipo "SVM" luego de ejecutar un modelo PCA.
#
# Estos serán configurados con diversos hiperparámetros a fin de encontrar el resultado más óptimo para este data set.
#
# La variable target del modelo es la columna [Target] de BTC_multiple_2.

# %% [markdown]
# ## Se genera un modelo PCA

# %%
# Se genera la variable X (variables) e y (target)
X = BTC_multiple_2.drop ('Target', axis=1)
y = BTC_multiple_2 ['Target']

# %%
# Se separa el data set en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Se normalizan los datos para que PCA otorgue mejores resultados
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Se aplica PCA
pca = PCA()
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Se analiza la varianza de cada componente
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([4.37623053e-01, 1.15032623e-01, 1.08431817e-01, 6.40911267e-02,
#        6.36633059e-02, 4.76579362e-02, 4.52855828e-02, 3.40902281e-02,
#        2.71378581e-02, 2.61683378e-02, 1.29449950e-02, 6.99377093e-03,
#        5.61555760e-03, 3.73433517e-03, 1.38749235e-03, 7.72153714e-05,
#        3.66053491e-05, 2.23233784e-05, 5.83679013e-06, 2.70824717e-32,
#        1.24076159e-33])

# %% [markdown]
# Observaciones:
# - Las primeras 11 variables expresan el 98% de la varianza de los datos.

# %%
# Se genera la variable X (variables) e y (target)
X = BTC_multiple_2.drop ('Target', axis=1)
y = BTC_multiple_2 ['Target']

# %%
# Se separa el data set en train y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# Se normalizan los datos para que PCA otorgue mejores resultados
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Se genera un nuevo PCA con 11 componentes (las variables que recogen el 98 % de la varianza de los datos)
pca = PCA(n_components=11)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)

# %%
# Se definen los parámetros de búsqueda
param_grid= {'kernel': ['rbf'],
             'C': [0.1, 1, 10, 100, 1000],
             'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
             'random_state':np.arange(1,5000,50),
             'class_weight': ['balanced'] }

from sklearn.model_selection import RandomizedSearchCV
grid_SVM = RandomizedSearchCV(SVC(), param_grid, refit=True, verbose=3, n_iter=100, cv=5)

# %%
grid_SVM.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=4551;, score=0.597 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=4551;, score=0.576 total time=   1.3s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=4551;, score=0.582 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=4551;, score=0.599 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=4551;, score=0.588 total time=   0.6s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2451;, score=0.604 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2451;, score=0.586 total time=   0.6s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2451;, score=0.550 total time=   0.6s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2451;, score=0.615 total time=   0.8s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2451;, score=0.609 total time=   0.9s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1701;, score=0.611 total time=   1.1s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1701;, score=0.614 total time=   0.9s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1701;, score=0.599 total time=   0.7s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1701;, score=0.609 total time=   0.6s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1701;, score=0.605 total time=   0.6s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=701;, score=0.621 total time=   0.6s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=701;, score=0.644 total time=   0.6s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=701;, score=0.624 total time=   0.6s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=701;, score=0.635 total time=   0.6s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=701;, score=0.616 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4801;, score=0.634 total time=   4.4s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4801;, score=0.654 total time=   4.5s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4801;, score=0.612 total time=   3.9s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4801;, score=0.608 total time=   4.2s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4801;, score=0.615 total time=   3.5s
# [CV 1/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=501;, score=0.585 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=501;, score=0.606 total time=   0.6s
# [CV 3/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=501;, score=0.595 total time=   0.6s
# [CV 4/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=501;, score=0.586 total time=   0.6s
# [CV 5/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=501;, score=0.601 total time=   0.6s
# [CV 1/5] END C=10, class_weight=balanced, gamma=1, kernel=rbf, random_state=3901;, score=0.584 total time=   0.7s
# [CV 2/5] END C=10, class_weight=balanced, gamma=1, kernel=rbf, random_state=3901;, score=0.632 total time=   0.7s
# [CV 3/5] END C=10, class_weight=balanced, gamma=1, kernel=rbf, random_state=3901;, score=0.588 total time=   0.7s
# [CV 4/5] END C=10, class_weight=balanced, gamma=1, kernel=rbf, random_state=3901;, score=0.603 total time=   0.7s
# [CV 5/5] END C=10, class_weight=balanced, gamma=1, kernel=rbf, random_state=3901;, score=0.588 total time=   0.7s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3351;, score=0.561 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3351;, score=0.534 total time=   0.6s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3351;, score=0.588 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3351;, score=0.541 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3351;, score=0.573 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=1651;, score=0.634 total time=   4.4s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=1651;, score=0.654 total time=   4.5s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=1651;, score=0.612 total time=   3.9s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=1651;, score=0.608 total time=   4.1s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=1651;, score=0.615 total time=   3.4s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3351;, score=0.618 total time=   0.6s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3351;, score=0.590 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3351;, score=0.548 total time=   0.6s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3351;, score=0.618 total time=   0.6s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3351;, score=0.605 total time=   0.7s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=4201;, score=0.561 total time=   0.7s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=4201;, score=0.534 total time=   0.7s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=4201;, score=0.588 total time=   0.7s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=4201;, score=0.541 total time=   0.7s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=4201;, score=0.573 total time=   0.7s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=2551;, score=0.590 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=2551;, score=0.635 total time=   0.6s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=2551;, score=0.592 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=2551;, score=0.621 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=2551;, score=0.601 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=351;, score=0.616 total time=   1.4s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=351;, score=0.644 total time=   1.4s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=351;, score=0.621 total time=   1.4s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=351;, score=0.621 total time=   1.3s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=351;, score=0.619 total time=   1.3s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3751;, score=0.618 total time=   0.6s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3751;, score=0.590 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3751;, score=0.548 total time=   0.6s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3751;, score=0.618 total time=   0.6s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=3751;, score=0.605 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4001;, score=0.617 total time=   0.6s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4001;, score=0.615 total time=   0.6s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4001;, score=0.609 total time=   0.6s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4001;, score=0.614 total time=   0.6s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4001;, score=0.606 total time=   0.6s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3601;, score=0.604 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3601;, score=0.586 total time=   0.6s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3601;, score=0.550 total time=   0.6s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3601;, score=0.615 total time=   0.6s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=3601;, score=0.609 total time=   0.6s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=901;, score=0.611 total time=   0.6s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=901;, score=0.614 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=901;, score=0.599 total time=   0.6s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=901;, score=0.609 total time=   0.6s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=901;, score=0.605 total time=   0.6s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=1001;, score=0.575 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=1001;, score=0.582 total time=   0.6s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=1001;, score=0.559 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=1001;, score=0.547 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=1, kernel=rbf, random_state=1001;, score=0.575 total time=   0.6s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=3301;, score=0.610 total time=   0.6s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=3301;, score=0.658 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=3301;, score=0.603 total time=   0.6s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=3301;, score=0.611 total time=   0.6s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=3301;, score=0.602 total time=   0.5s
# [CV 1/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=3151;, score=0.585 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=3151;, score=0.606 total time=   0.6s
# [CV 3/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=3151;, score=0.595 total time=   0.6s
# [CV 4/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=3151;, score=0.586 total time=   0.6s
# [CV 5/5] END C=1, class_weight=balanced, gamma=1, kernel=rbf, random_state=3151;, score=0.601 total time=   0.6s
# [CV 1/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=351;, score=0.555 total time=   0.6s
# [CV 2/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=351;, score=0.531 total time=   0.6s
# [CV 3/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=351;, score=0.589 total time=   0.6s
# [CV 4/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=351;, score=0.541 total time=   0.6s
# [CV 5/5] END C=1, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=351;, score=0.566 total time=   0.6s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=
7s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=701;, score=0.618 total time=   0.7s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3601;, score=0.621 total time=   0.6s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3601;, score=0.644 total time=   0.6s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3601;, score=0.624 total time=   0.6s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3601;, score=0.635 total time=   0.6s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=3601;, score=0.616 total time=   0.6s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4951;, score=0.610 total time=   0.6s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4951;, score=0.658 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4951;, score=0.603 total time=   0.6s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4951;, score=0.611 total time=   0.6s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.1, kernel=rbf, random_state=4951;, score=0.602 total time=   0.6s
# [CV 1/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=201;, score=0.561 total time=   0.6s
# [CV 2/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=201;, score=0.534 total time=   0.6s
# [CV 3/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=201;, score=0.588 total time=   0.6s
# [CV 4/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=201;, score=0.541 total time=   0.6s
# [CV 5/5] END C=0.1, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=201;, score=0.573 total time=   0.9s
# [CV 1/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1151;, score=0.627 total time=   0.8s
# [CV 2/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1151;, score=0.640 total time=   0.7s
# [CV 3/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1151;, score=0.650 total time=   0.9s
# [CV 4/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1151;, score=0.640 total time=   0.8s
# [CV 5/5] END C=1000, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=1151;, score=0.618 total time=   0.7s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=2801;, score=0.621 total time=   0.7s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=2801;, score=0.644 total time=   0.7s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=2801;, score=0.624 total time=   0.6s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=2801;, score=0.635 total time=   0.6s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.01, kernel=rbf, random_state=2801;, score=0.616 total time=   0.6s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=2151;, score=0.597 total time=   0.5s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=2151;, score=0.611 total time=   0.6s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=2151;, score=0.560 total time=   0.5s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=2151;, score=0.609 total time=   0.6s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=2151;, score=0.605 total time=   0.6s
# [CV 1/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2151;, score=0.611 total time=   0.6s
# [CV 2/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2151;, score=0.614 total time=   0.6s
# [CV 3/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2151;, score=0.599 total time=   0.6s
# [CV 4/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2151;, score=0.609 total time=   0.5s
# [CV 5/5] END C=10, class_weight=balanced, gamma=0.001, kernel=rbf, random_state=2151;, score=0.605 total time=   0.6s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4701;, score=0.597 total time=   0.5s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4701;, score=0.611 total time=   0.6s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4701;, score=0.560 total time=   0.6s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4701;, score=0.609 total time=   0.5s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=4701;, score=0.605 total time=   0.6s
# [CV 1/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=1401;, score=0.597 total time=   0.5s
# [CV 2/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=1401;, score=0.611 total time=   0.6s
# [CV 3/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=1401;, score=0.560 total time=   0.6s
# [CV 4/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=1401;, score=0.609 total time=   0.6s
# [CV 5/5] END C=100, class_weight=balanced, gamma=0.0001, kernel=rbf, random_state=1401;, score=0.605 total time=   0.6s
# RandomizedSearchCV(cv=5, estimator=SVC(), n_iter=100,
#                    param_distributions={'C': [0.1, 1, 10, 100, 1000],
#                                         'class_weight': ['balanced'],
#                                         'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                                         'kernel': ['rbf'],
#                                         'random_state': array([   1,   51,  101,  151,  201,  251,  301,  351,  401,  451,  501,
#         551,  601,  651,  701,  751,  801,  851,  901,  951, 1001, 1051,
#        1101, 1151, 1201, 1251, 1301, 1351, 1401, 1451, 1501, 1551, 1601,
#        1651, 1701, 1751, 1801, 1851, 1901, 1951, 2001, 2051, 2101, 2151,
#        2201, 2251, 2301, 2351, 2401, 2451, 2501, 2551, 2601, 2651, 2701,
#        2751, 2801, 2851, 2901, 2951, 3001, 3051, 3101, 3151, 3201, 3251,
#        3301, 3351, 3401, 3451, 3501, 3551, 3601, 3651, 3701, 3751, 3801,
#        3851, 3901, 3951, 4001, 4051, 4101, 4151, 4201, 4251, 4301, 4351,
#        4401, 4451, 4501, 4551, 4601, 4651, 4701, 4751, 4801, 4851, 4901,
#        4951])},
#                    verbose=3)

# %%
# print best parameter after tuning
print(grid_SVM.best_params_)
  
# print how our model looks after hyper-parameter tuning
print(grid_SVM.best_estimator_)
# Out:
# {'random_state': 4901, 'kernel': 'rbf', 'gamma': 0.001, 'class_weight': 'balanced', 'C': 1000}
# SVC(C=1000, class_weight='balanced', gamma=0.001, random_state=4901)

# %%
# Se crea el modelo SVM 
modelo = SVC(C = 1000, kernel = 'rbf', gamma=0.001, class_weight='balanced', random_state=4901)

# %%
# Se entrena al modelo
modelo.fit(X_train, y_train)
# Out:
# SVC(C=1000, class_weight='balanced', gamma=0.001, random_state=4901)

# %%
# Se busca conocer las predicciones del modelo
y_train_pred = modelo.predict(X_train)
y_test_pred = modelo.predict(X_test)

# %%
# Se calcula el accuracy en los datos de train
train_accuracy = accuracy_score(y_train, y_train_pred)
print('% de aciertos sobre el set de evaluación para train:', train_accuracy)

# Se calcula el accuracy en los datos de test
test_accuracy = accuracy_score(y_test, y_test_pred)
print('% de aciertos sobre el set de evaluación para test:', test_accuracy)
# Out:
# % de aciertos sobre el set de evaluación para train: 0.6472800925925926
# % de aciertos sobre el set de evaluación para test: 0.6192129629629629

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix

# Predicciones
predictions = modelo.predict(X_test)

#Matriz de Confusión
print(confusion_matrix(y_test, predictions))

#Ploteamos la Matriz
plot_confusion_matrix(modelo, X_test, y_test)
plt.show()
# Out:
# [[328 103]
#  [226 207]]

# %% [markdown]
# Observaciones:
# - Al modelo le cuesta diferenciar las clases.
# - Posee un gran número de falsos negativos.

# %%
# Accuracy
print(f"Accuracy of the classifier is: {accuracy_score(y_test, predictions)}")

# Precision
from sklearn.metrics import precision_score
print(f"Precision Score of the classifier is: {precision_score(y_test, predictions)}")

# Recall
from sklearn.metrics import recall_score
print(f"Recall Score of the classifier is: {recall_score(y_test, predictions)}")

# Calculo del F1 score
from sklearn.metrics import f1_score
print(f"F1 Score of the classifier is: {f1_score(y_test, predictions)}")
# Out:
# Accuracy of the classifier is: 0.6192129629629629
# Precision Score of the classifier is: 0.667741935483871
# Recall Score of the classifier is: 0.4780600461893764
# F1 Score of the classifier is: 0.557200538358008

# %% [markdown]
# Observaciones:
# - El mejor modelo predice en un 62% de los casos en los que el precio de BTC sube o baja.
